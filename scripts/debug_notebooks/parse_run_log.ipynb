# %%
file1 = open(r'Z:\bayarea_urbansim\runs\run290.log', 'r')
Lines = file1.readlines()

# %%
for line in Lines:
    if (line.strip()[:12] == 'Running step') or (line.strip()[:17] == 'Running iteration'):
        print(line.strip())
# Out:
# Running iteration 1 with iteration value 2010
# Running step 'slr_inundate'
# Running step 'slr_remove_dev'
# Running step 'eq_code_buildings'
# Running step 'earthquake_demolish'
# Running step 'neighborhood_vars'
# Running step 'regional_vars'
# Running step 'rsh_simulate'
# Running step 'rrh_simulate'
# Running step 'nrh_simulate'
# Running step 'assign_tenure_to_new_units'
# Running step 'household_relocation'
# Running step 'households_transition'
# Running step 'reconcile_unplaced_households'
# Running step 'jobs_transition'
# Running step 'hlcm_owner_lowincome_simulate'
# Running step 'hlcm_renter_lowincome_simulate'
# Running step 'hlcm_owner_simulate'
# Running step 'hlcm_renter_simulate'
# Running step 'hlcm_owner_simulate_no_unplaced'
# Running step 'hlcm_owner_lowincome_simulate_no_unplaced'
# Running step 'hlcm_renter_simulate_no_unplaced'
# Running step 'hlcm_renter_lowincome_simulate_no_unplaced'
# Running step 'reconcile_placed_households'
# ...

# %%
'Running iteration 1 with iteration value 2010'[:17]
# Out:
# 'Running iteration'

# %%
"Running step 'slr_inundate'"[:12]
# Out:
# 'Running step'
