# %%
# %load_ext autoreload
# %autoreload 2
import models
import urbansim.sim.simulation as sim

# %%
sim.run(["build_networks"])
# Out:
# Running model 'build_networks'
# Time to execute model 'build_networks': 5.35s
# Total time to execute: 5.35s

# %%
sim.run(["neighborhood_vars"])
# Out:
# Running model 'neighborhood_vars'
# Computing accessibility variables
# Computing sum_residential_units
# Computing sum_nonresidential_units
# Computing ave_unit_sqft
# Computing ave_lot_sqft
# Computing population
# Computing poor
# Computing renters
# Computing sfdu
# Computing hhsize
# Computing jobs
# Computing ave_income
# Time to execute model 'neighborhood_vars': 11.52s
# Total time to execute: 11.52s

# %% [markdown]
# ## Hedonic Estimation

# %%
sim.run(["rsh_estimate"])
# Out:
# Running model 'rsh_estimate'
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     np.log1p(sale_price_flt)   R-squared:                       0.217
# Model:                                  OLS   Adj. R-squared:                  0.216
# Method:                       Least Squares   F-statistic:                     302.7
# Date:                      Wed, 06 Aug 2014   Prob (F-statistic):               0.00
# Time:                              14:12:04   Log-Likelihood:                -4992.8
# No. Observations:                      8738   AIC:                         1.000e+04
# Df Residuals:                          8729   BIC:                         1.007e+04
# Df Model:                                 8
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        8.6208      0.113     76.353      0.000         8.399     8.842
# I(year_built < 1940)[T.True]     0.0436      0.010      4.357      0.000         0.024     0.063
# I(year_built > 2005)[T.True]     0.0713      0.076      0.932      0.351        -0.079     0.221
# np.log1p(unit_sqft)             -0.4346      0.010    -44.067      0.000        -0.454    -0.415
# np.log1p(unit_lot_size)          0.0634      0.007      8.871      0.000         0.049     0.077
# sum_residential_units            0.0837      0.007     12.529      0.000         0.071     0.097
# ave_unit_sqft                   -0.0016      0.026     -0.060      0.952        -0.053     0.050
# ave_lot_sqft                    -0.2809      0.016    -17.135      0.000        -0.313    -0.249
# ave_income                       0.1621      0.014     11.254      0.000         0.134     0.190
# ==============================================================================
# Omnibus:                      867.822   Durbin-Watson:                   1.324
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2405.219
# Skew:                          -0.551   Prob(JB):                         0.00
# Kurtosis:                       5.322   Cond. No.                         515.
# ==============================================================================
# Time to execute model 'rsh_estimate': 0.58s
# Total time to execute: 0.58s

# %%
sim.run(["rrh_estimate"])
# Out:
# Running model 'rrh_estimate'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Wed, 06 Aug 2014   Prob (F-statistic):           1.64e-17
# Time:                        14:12:04   Log-Likelihood:                 95.640
# No. Observations:                 178   AIC:                            -179.3
# Df Residuals:                     172   BIC:                            -160.2
# Df Model:                           5
# =========================================================================================
#                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# Intercept                 2.5404      0.382      6.652      0.000         1.787     3.294
# np.log1p(unit_sqft)      -0.1953      0.030     -6.471      0.000        -0.255    -0.136
# sum_residential_units    -0.0268      0.024     -1.110      0.268        -0.074     0.021
# ave_unit_sqft             0.0006      0.015      0.042      0.967        -0.028     0.030
# ave_lot_sqft             -0.0365      0.027     -1.336      0.183        -0.090     0.017
# jobs                      0.0752      0.015      5.049      0.000         0.046     0.105
# ==============================================================================
# Omnibus:                       11.211   Durbin-Watson:                   1.302
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               27.319
# Skew:                          -0.030   Prob(JB):                     1.17e-06
# Kurtosis:                       4.918   Cond. No.                         662.
# ==============================================================================
# Time to execute model 'rrh_estimate': 0.23s
# Total time to execute: 0.23s

# %%
sim.run(["nrh_estimate"])
# Out:
# Running model 'nrh_estimate'
# REGRESSION RESULTS FOR SEGMENT Retail
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.316
# Date:                Wed, 06 Aug 2014   Prob (F-statistic):              0.262
# Time:                        14:12:05   Log-Likelihood:                -73.855
# No. Observations:                 124   AIC:                             159.7
# Df Residuals:                     118   BIC:                             176.6
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.8609      2.476     -0.348      0.729        -5.765     4.043
# I(year_built < 1940)[T.True]    -0.0941      0.105     -0.896      0.372        -0.302     0.114
# I(year_built > 2005)[T.True]    -0.1046      0.246     -0.426      0.671        -0.591     0.382
# np.log1p(stories)               -0.0755      0.110     -0.684      0.495        -0.294     0.143
# ave_income                       0.2976      0.193      1.545      0.125        -0.084     0.679
# jobs                             0.1151      0.046      2.482      0.014         0.023     0.207
# ==============================================================================
# Omnibus:                       15.597   Durbin-Watson:                   2.433
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.800
# Skew:                           0.492   Prob(JB):                     1.24e-07
# Kurtosis:                       5.277   Cond. No.                         910.
# ==============================================================================
# REGRESSION RESULTS FOR SEGMENT Office
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     3.490
# Date:                Wed, 06 Aug 2014   Prob (F-statistic):            0.00426
# Time:                        14:12:05   Log-Likelihood:                -168.79
# No. Observations:                 385   AIC:                             349.6
# Df Residuals:                     379   BIC:                             373.3
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.5244      0.207     17.017      0.000         3.117     3.932
# I(year_built < 1940)[T.True]    -0.0787      0.046     -1.698      0.090        -0.170     0.012
# I(year_built > 2005)[T.True]    -0.0188      0.173     -0.109      0.913        -0.358     0.321
# np.log1p(stories)                0.0493      0.035      1.401      0.162        -0.020     0.118
# ave_income                      -0.0417      0.023     -1.831      0.068        -0.086     0.003
# jobs                             0.0194      0.018      1.079      0.281        -0.016     0.055
# ==============================================================================
# Omnibus:                      106.606   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              544.913
# Skew:                           1.074   Prob(JB):                    4.72e-119
# Kurtosis:                       8.418   Cond. No.                         167.
# ==============================================================================
# REGRESSION RESULTS FOR SEGMENT Industrial
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     931.2
# Date:                Wed, 06 Aug 2014   Prob (F-statistic):           1.19e-66
# Time:                        14:12:05   Log-Likelihood:                -21.284
# No. Observations:                  81   AIC:                             52.57
# Df Residuals:                      76   BIC:                             64.54
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.5185      0.347      7.266      0.000         1.828     3.209
# I(year_built < 1940)[T.True]     0.0130      0.083      0.157      0.876        -0.152     0.178
# I(year_built > 2005)[T.True]  -1.55e-16   2.69e-16     -0.576      0.566     -6.91e-16  3.81e-16
# np.log1p(stories)                0.0788      0.134      0.588      0.558        -0.188     0.346
# ave_income                      -0.0388      0.039     -0.994      0.323        -0.116     0.039
# jobs                             0.0338      0.035      0.956      0.342        -0.037     0.104
# ==============================================================================
# Omnibus:                        8.537   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               18.123
# Skew:                           0.117   Prob(JB):                     0.000116
# Kurtosis:                       5.305   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is -4.88e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Time to execute model 'nrh_estimate': 0.59s
# Total time to execute: 0.59s

# %% [markdown]
# ## Hedonic Simulation

# %%
sim.run(["rsh_simulate", "rrh_simulate", "nrh_simulate"])
# Out:
# Running model 'rsh_simulate'
# Dropped 3118 rows because they contained nans
# count    138407.000000
# mean        543.457014
# std         171.494622
# min          14.502544
# 25%         461.634613
# 50%         528.977635
# 75%         596.176895
# max       10138.582366
# dtype: float64
# Time to execute model 'rsh_simulate': 1.16s
# Running model 'rrh_simulate'
# Dropped 2 rows because they contained nans
# count    140780.000000
# mean          3.412905
# std           0.499166
# min           0.630713
# 25%           3.151931
# 50%           3.343975
# 75%           3.580759
# max          15.340111
# dtype: float64
# Time to execute model 'rrh_simulate': 0.51s
# Running model 'nrh_simulate'
# Dropped 3118 rows because they contained nans
# count    10203.000000
# mean        23.982738
# std          7.233765
# min          0.480017
# 25%         22.415323
# 50%         26.249629
# 75%         28.755369
# max         40.735691
# dtype: float64
# Time to execute model 'nrh_simulate': 0.45s
# Total time to execute: 2.12s

# %% [markdown]
# ## LCM Estimation

# %%
sim.run(["hlcmo_estimate"])
# Out:
# Running model 'hlcmo_estimate'
# Dropped 14198 rows because they contained nans
# LCM RESULTS FOR SEGMENT 0
# Null Log-liklihood: -65540.782
# Log-liklihood at convergence: -64530.617
# Log-liklihood Ratio: 0.015
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -1.820   |   0.158    | -11.500 |
# | np.log1p(unit_sqft)               |    -0.886   |   0.065    | -13.679 |
# | sum_residential_units             |    -1.728   |   0.071    | -24.487 |
# | ave_unit_sqft                     |    0.159    |   0.059    |  2.682  |
# | ave_lot_sqft                      |    -0.450   |   0.053    |  -8.574 |
# | ave_income                        |    -1.294   |   0.146    |  -8.880 |
# | hhsize                            |    -3.000   |   0.142    | -21.192 |
# | jobs                              |    0.134    |   0.020    |  6.569  |
# | poor                              |    -0.145   |   0.079    |  -1.834 |
# | population                        |    1.988    |   0.072    |  27.526 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -67894.024
# Log-liklihood at convergence: -67336.061
# Log-liklihood Ratio: 0.008
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -2.446   |   0.153    | -15.965 |
# | np.log1p(unit_sqft)               |    -1.179   |   0.063    | -18.733 |
# | sum_residential_units             |    -1.087   |   0.070    | -15.586 |
# | ave_unit_sqft                     |    0.063    |   0.056    |  1.119  |
# | ave_lot_sqft                      |    -0.730   |   0.052    | -13.899 |
# | ave_income                        |    -0.404   |   0.143    |  -2.822 |
# | hhsize                            |    -2.282   |   0.142    | -16.014 |
# | jobs                              |    0.122    |   0.020    |  5.973  |
# | poor                              |    -0.163   |   0.078    |  -2.096 |
# | population                        |    1.378    |   0.073    |  18.959 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -68050.600
# Log-liklihood at convergence: -67505.413
# Log-liklihood Ratio: 0.008
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -2.771   |   0.152    | -18.225 |
# | np.log1p(unit_sqft)               |    -1.339   |   0.062    | -21.643 |
# | sum_residential_units             |    -1.029   |   0.069    | -14.893 |
# | ave_unit_sqft                     |    0.126    |   0.055    |  2.277  |
# | ave_lot_sqft                      |    -0.725   |   0.053    | -13.764 |
# | ave_income                        |    -0.168   |   0.143    |  -1.173 |
# | hhsize                            |    -2.150   |   0.141    | -15.220 |
# | jobs                              |    0.120    |   0.020    |  5.900  |
# | poor                              |    -0.397   |   0.077    |  -5.125 |
# | population                        |    1.566    |   0.073    |  21.451 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -68170.334
# Log-liklihood at convergence: -67179.584
# Log-liklihood Ratio: 0.015
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -3.000   |   0.145    | -20.693 |
# | np.log1p(unit_sqft)               |    -1.435   |   0.059    | -24.418 |
# | sum_residential_units             |    -1.056   |   0.068    | -15.453 |
# | ave_unit_sqft                     |    0.242    |   0.057    |  4.213  |
# | ave_lot_sqft                      |    -0.881   |   0.052    | -16.868 |
# | ave_income                        |    1.033    |   0.138    |  7.473  |
# | hhsize                            |    -3.000   |   0.148    | -20.245 |
# | jobs                              |    0.183    |   0.021    |  8.804  |
# | poor                              |    -0.328   |   0.077    |  -4.254 |
# | population                        |    1.493    |   0.071    |  20.912 |
# +-----------------------------------+-------------+------------+---------+
# Time to execute model 'hlcmo_estimate': 41.22s
# Total time to execute: 41.22s

# %%
sim.run(["hlcmr_estimate"])
# Out:
# Running model 'hlcmr_estimate'
# Dropped 11825 rows because they contained nans
# LCM RESULTS FOR SEGMENT 0
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -18314.744
# Log-liklihood Ratio: 0.205
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.814    |  -3.686 |
# | np.log1p(unit_sqft)        |    -0.896   |   0.133    |  -6.759 |
# | sum_residential_units      |    -0.465   |   0.129    |  -3.591 |
# | ave_unit_sqft              |    -0.049   |   0.108    |  -0.458 |
# | ave_lot_sqft               |    0.622    |   0.056    |  11.107 |
# | ave_income                 |    -1.168   |   0.136    |  -8.620 |
# | hhsize                     |    -3.000   |   0.268    | -11.198 |
# | jobs                       |    0.343    |   0.061    |  5.642  |
# | poor                       |    0.907    |   0.099    |  9.193  |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20080.901
# Log-liklihood Ratio: 0.128
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.784    |  -3.828 |
# | np.log1p(unit_sqft)        |    -1.047   |   0.128    |  -8.164 |
# | sum_residential_units      |    0.150    |   0.129    |  1.164  |
# | ave_unit_sqft              |    -0.429   |   0.110    |  -3.901 |
# | ave_lot_sqft               |    0.423    |   0.053    |  8.021  |
# | ave_income                 |    -0.811   |   0.133    |  -6.083 |
# | hhsize                     |    -3.000   |   0.276    | -10.889 |
# | jobs                       |    0.135    |   0.059    |  2.294  |
# | poor                       |    0.311    |   0.096    |  3.251  |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20658.987
# Log-liklihood Ratio: 0.103
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.725    |  -4.139 |
# | np.log1p(unit_sqft)        |    -1.133   |   0.119    |  -9.493 |
# | sum_residential_units      |    0.440    |   0.121    |  3.624  |
# | ave_unit_sqft              |    -0.511   |   0.105    |  -4.878 |
# | ave_lot_sqft               |    0.212    |   0.051    |  4.134  |
# | ave_income                 |    -0.057   |   0.129    |  -0.440 |
# | hhsize                     |    -3.000   |   0.269    | -11.165 |
# | jobs                       |    0.222    |   0.054    |  4.122  |
# | poor                       |    -0.232   |   0.091    |  -2.543 |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20480.087
# Log-liklihood Ratio: 0.111
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.698    |  -4.297 |
# | np.log1p(unit_sqft)        |    -1.201   |   0.116    | -10.392 |
# | sum_residential_units      |    0.580    |   0.123    |  4.727  |
# | ave_unit_sqft              |    -0.170   |   0.101    |  -1.685 |
# | ave_lot_sqft               |    -0.089   |   0.059    |  -1.497 |
# | ave_income                 |    0.982    |   0.128    |  7.694  |
# | hhsize                     |    -3.000   |   0.283    | -10.599 |
# | jobs                       |    0.306    |   0.053    |  5.784  |
# | poor                       |    -0.490   |   0.093    |  -5.263 |
# +----------------------------+-------------+------------+---------+
# Time to execute model 'hlcmr_estimate': 13.92s
# Total time to execute: 13.92s

# %%
sim.run(["elcm_estimate"])
# Out:
# Running model 'elcm_estimate'
# Dropped 142402 rows because they contained nans
# LCM RESULTS FOR SEGMENT 11
# Null Log-liklihood: -2256.533
# Log-liklihood at convergence: -1735.835
# Log-liklihood Ratio: 0.231
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.000    |   0.255    |  3.927  |
# | np.log1p(stories)              |    0.494    |   0.082    |  6.039  |
# | sum_residential_units          |    -1.115   |   0.467    |  -2.389 |
# | ave_unit_sqft                  |    1.505    |   0.281    |  5.352  |
# | ave_lot_sqft                   |    -2.157   |   0.222    |  -9.707 |
# | ave_income                     |    -1.086   |   0.256    |  -4.245 |
# | hhsize                         |    -3.000   |   1.269    |  -2.364 |
# | jobs                           |    1.101    |   0.081    |  13.526 |
# | poor                           |    -0.509   |   0.328    |  -1.553 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 21
#
# Null Log-liklihood: -515.779
# Log-liklihood at convergence: -192.483
# Log-liklihood Ratio: 0.627
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.001    |   1.453    |  0.689  |
# | np.log1p(stories)              |    0.382    |   0.211    |  1.809  |
# | sum_residential_units          |    -0.426   |   3.098    |  -0.138 |
# | ave_unit_sqft                  |    -3.000   |   1.883    |  -1.594 |
# | ave_lot_sqft                   |    3.000    |   1.355    |  2.214  |
# | ave_income                     |    3.000    |   1.392    |  2.155  |
# | hhsize                         |    3.000    |   6.547    |  0.458  |
# | jobs                           |    2.431    |   0.579    |  4.197  |
# | poor                           |    -0.270   |   2.216    |  -0.122 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 22
#
# Null Log-liklihood: -22183.105
# Log-liklihood at convergence: -3379.931
# Log-liklihood Ratio: 0.848
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    3.000    |   0.161    |  18.594 |
# | np.log1p(stories)              |    -1.644   |   0.051    | -32.392 |
# | sum_residential_units          |    -0.241   |   0.326    |  -0.739 |
# | ave_unit_sqft                  |    -2.542   |   0.175    | -14.549 |
# | ave_lot_sqft                   |    3.000    |   0.066    |  45.740 |
# | ave_income                     |    1.499    |   0.180    |  8.349  |
# | hhsize                         |    3.000    |   0.934    |  3.212  |
# | jobs                           |    2.841    |   0.085    |  33.612 |
# | poor                           |    -0.905   |   0.226    |  -4.010 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 23
#
# Null Log-liklihood: -44734.623
# Log-liklihood at convergence: -41104.669
# Log-liklihood Ratio: 0.081
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.526   |   0.036    | -14.794 |
# | np.log1p(stories)              |    0.780    |   0.021    |  37.219 |
# | sum_residential_units          |    -0.861   |   0.064    | -13.549 |
# | ave_unit_sqft                  |    0.335    |   0.048    |  6.925  |
# | ave_lot_sqft                   |    0.733    |   0.034    |  21.529 |
# | ave_income                     |    1.747    |   0.044    |  40.077 |
# | hhsize                         |    1.521    |   0.183    |  8.304  |
# | jobs                           |    0.553    |   0.017    |  32.637 |
# | poor                           |    0.597    |   0.047    |  12.794 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 31
#
# Null Log-liklihood: -29905.975
# Log-liklihood at convergence: -24806.561
# Log-liklihood Ratio: 0.171
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.548    |   0.053    |  10.391 |
# | np.log1p(stories)              |    -0.218   |   0.032    |  -6.799 |
# | sum_residential_units          |    -2.391   |   0.096    | -25.013 |
# | ave_unit_sqft                  |    0.279    |   0.110    |  2.544  |
# | ave_lot_sqft                   |    -1.436   |   0.093    | -15.491 |
# | ave_income                     |    0.384    |   0.052    |  7.425  |
# | hhsize                         |    -3.000   |   0.237    | -12.636 |
# | jobs                           |    1.351    |   0.030    |  44.916 |
# | poor                           |    0.302    |   0.069    |  4.343  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 32
#
# Null Log-liklihood: -18158.186
# Log-liklihood at convergence: -15756.548
# Log-liklihood Ratio: 0.132
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.406   |   0.068    |  -5.986 |
# | np.log1p(stories)              |    0.551    |   0.032    |  17.224 |
# | sum_residential_units          |    -3.000   |   0.102    | -29.381 |
# | ave_unit_sqft                  |    1.815    |   0.098    |  18.544 |
# | ave_lot_sqft                   |    0.167    |   0.075    |  2.215  |
# | ave_income                     |    3.000    |   0.083    |  36.331 |
# | hhsize                         |    0.992    |   0.360    |  2.752  |
# | jobs                           |    1.329    |   0.031    |  42.987 |
# | poor                           |    2.132    |   0.077    |  27.777 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 33
#
# Null Log-liklihood: -19682.497
# Log-liklihood at convergence: -18138.776
# Log-liklihood Ratio: 0.078
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.645   |   0.059    | -11.000 |
# | np.log1p(stories)              |    0.473    |   0.032    |  14.637 |
# | sum_residential_units          |    -1.457   |   0.117    | -12.422 |
# | ave_unit_sqft                  |    0.630    |   0.123    |  5.115  |
# | ave_lot_sqft                   |    -0.001   |   0.099    |  -0.008 |
# | ave_income                     |    1.715    |   0.072    |  23.963 |
# | hhsize                         |    0.410    |   0.315    |  1.304  |
# | jobs                           |    0.916    |   0.032    |  28.549 |
# | poor                           |    0.816    |   0.083    |  9.866  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 42
#
# Null Log-liklihood: -51048.312
# Log-liklihood at convergence: -40614.156
# Log-liklihood Ratio: 0.204
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.009    |   0.036    |  0.239  |
# | np.log1p(stories)              |    0.839    |   0.016    |  53.348 |
# | sum_residential_units          |    -0.830   |   0.069    | -12.053 |
# | ave_unit_sqft                  |    -0.617   |   0.048    | -12.841 |
# | ave_lot_sqft                   |    0.750    |   0.030    |  25.146 |
# | ave_income                     |    0.548    |   0.046    |  11.903 |
# | hhsize                         |    1.076    |   0.199    |  5.409  |
# | jobs                           |    0.774    |   0.016    |  47.693 |
# | poor                           |    0.061    |   0.048    |  1.252  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 44
#
# Null Log-liklihood: -42570.193
# Log-liklihood at convergence: -38153.063
# Log-liklihood Ratio: 0.104
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.943    |   0.044    |  21.522 |
# | np.log1p(stories)              |    0.694    |   0.021    |  33.478 |
# | sum_residential_units          |    -0.238   |   0.087    |  -2.748 |
# | ave_unit_sqft                  |    0.384    |   0.059    |  6.474  |
# | ave_lot_sqft                   |    -0.035   |   0.039    |  -0.898 |
# | ave_income                     |    0.497    |   0.048    |  10.292 |
# | hhsize                         |    -1.309   |   0.224    |  -5.854 |
# | jobs                           |    0.330    |   0.020    |  16.244 |
# | poor                           |    -0.263   |   0.061    |  -4.293 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 45
#
# Null Log-liklihood: -36302.557
# Log-liklihood at convergence: -33164.488
# Log-liklihood Ratio: 0.086
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.185    |   0.052    |  22.937 |
# | np.log1p(stories)              |    0.432    |   0.022    |  19.640 |
# | sum_residential_units          |    -0.469   |   0.089    |  -5.277 |
# | ave_unit_sqft                  |    0.560    |   0.081    |  6.901  |
# | ave_lot_sqft                   |    0.001    |   0.061    |  0.020  |
# | ave_income                     |    -0.206   |   0.047    |  -4.406 |
# | hhsize                         |    -3.000   |   0.233    | -12.857 |
# | jobs                           |    0.200    |   0.023    |  8.725  |
# | poor                           |    0.202    |   0.060    |  3.352  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 48
#
# Null Log-liklihood: -20502.218
# Log-liklihood at convergence: -15345.423
# Log-liklihood Ratio: 0.252
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.140    |   0.066    |  2.114  |
# | np.log1p(stories)              |    0.410    |   0.026    |  15.766 |
# | sum_residential_units          |    -2.329   |   0.094    | -24.676 |
# | ave_unit_sqft                  |    0.390    |   0.089    |  4.370  |
# | ave_lot_sqft                   |    -0.396   |   0.069    |  -5.771 |
# | ave_income                     |    0.664    |   0.060    |  10.984 |
# | hhsize                         |    -3.000   |   0.237    | -12.661 |
# | jobs                           |    1.024    |   0.021    |  48.916 |
# | poor                           |    0.399    |   0.068    |  5.899  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 49
#
# Null Log-liklihood: -12130.018
# Log-liklihood at convergence: -9282.531
# Log-liklihood Ratio: 0.235
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.334   |   0.111    |  -3.017 |
# | np.log1p(stories)              |    -0.037   |   0.085    |  -0.436 |
# | sum_residential_units          |    -2.980   |   0.116    | -25.633 |
# | ave_unit_sqft                  |    -0.094   |   0.150    |  -0.624 |
# | ave_lot_sqft                   |    0.779    |   0.063    |  12.372 |
# | ave_income                     |    0.036    |   0.144    |  0.250  |
# | hhsize                         |    3.000    |   0.515    |  5.824  |
# | jobs                           |    0.594    |   0.041    |  14.462 |
# | poor                           |    2.101    |   0.064    |  32.786 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 51
#
# Null Log-liklihood: -47861.534
# Log-liklihood at convergence: -35450.158
# Log-liklihood Ratio: 0.259
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.282   |   0.037    |  -7.645 |
# | np.log1p(stories)              |    0.266    |   0.016    |  16.694 |
# | sum_residential_units          |    -0.466   |   0.085    |  -5.456 |
# | ave_unit_sqft                  |    0.565    |   0.076    |  7.475  |
# | ave_lot_sqft                   |    -0.752   |   0.058    | -12.933 |
# | ave_income                     |    -0.201   |   0.048    |  -4.201 |
# | hhsize                         |    -3.000   |   0.259    | -11.574 |
# | jobs                           |    1.178    |   0.019    |  61.914 |
# | poor                           |    -0.715   |   0.061    | -11.721 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 52
#
# Null Log-liklihood: -53862.070
# Log-liklihood at convergence: -25509.343
# Log-liklihood Ratio: 0.526
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.777    |   0.080    |  9.709  |
# | np.log1p(stories)              |    1.022    |   0.015    |  65.911 |
# | sum_residential_units          |    -1.492   |   0.126    | -11.806 |
# | ave_unit_sqft                  |    -2.132   |   0.083    | -25.731 |
# | ave_lot_sqft                   |    0.993    |   0.062    |  16.107 |
# | ave_income                     |    2.841    |   0.068    |  41.645 |
# | hhsize                         |    -3.000   |   0.387    |  -7.760 |
# | jobs                           |    1.387    |   0.027    |  51.029 |
# | poor                           |    0.377    |   0.092    |  4.113  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 53
#
# Null Log-liklihood: -37237.406
# Log-liklihood at convergence: -31769.090
# Log-liklihood Ratio: 0.147
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.350    |   0.055    |  6.328  |
# | np.log1p(stories)              |    0.868    |   0.019    |  44.670 |
# | sum_residential_units          |    -0.019   |   0.090    |  -0.212 |
# | ave_unit_sqft                  |    -1.210   |   0.053    | -22.770 |
# | ave_lot_sqft                   |    0.041    |   0.033    |  1.230  |
# | ave_income                     |    1.004    |   0.054    |  18.675 |
# | hhsize                         |    -3.000   |   0.272    | -11.042 |
# | jobs                           |    0.338    |   0.018    |  19.123 |
# | poor                           |    -0.416   |   0.067    |  -6.196 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 54
#
# Null Log-liklihood: -55828.478
# Log-liklihood at convergence: -34247.753
# Log-liklihood Ratio: 0.387
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.298    |   0.045    |  6.570  |
# | np.log1p(stories)              |    0.772    |   0.013    |  59.671 |
# | sum_residential_units          |    -0.755   |   0.086    |  -8.754 |
# | ave_unit_sqft                  |    -1.412   |   0.055    | -25.684 |
# | ave_lot_sqft                   |    1.009    |   0.036    |  27.865 |
# | ave_income                     |    1.499    |   0.051    |  29.389 |
# | hhsize                         |    -3.000   |   0.279    | -10.753 |
# | jobs                           |    1.065    |   0.018    |  58.842 |
# | poor                           |    -0.071   |   0.064    |  -1.118 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 55
#
# Null Log-liklihood: -5705.806
# Log-liklihood at convergence: -3337.697
# Log-liklihood Ratio: 0.415
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.672    |   0.189    |  3.562  |
# | np.log1p(stories)              |    0.860    |   0.043    |  19.985 |
# | sum_residential_units          |    -1.593   |   0.379    |  -4.209 |
# | ave_unit_sqft                  |    -1.141   |   0.318    |  -3.591 |
# | ave_lot_sqft                   |    0.207    |   0.255    |  0.813  |
# | ave_income                     |    3.000    |   0.199    |  15.091 |
# | hhsize                         |    -1.560   |   1.057    |  -1.475 |
# | jobs                           |    1.446    |   0.076    |  18.923 |
# | poor                           |    0.604    |   0.272    |  2.226  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 56
#
# Null Log-liklihood: -38595.931
# Log-liklihood at convergence: -32849.008
# Log-liklihood Ratio: 0.149
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.367    |   0.043    |  8.550  |
# | np.log1p(stories)              |    0.693    |   0.018    |  39.300 |
# | sum_residential_units          |    -0.766   |   0.093    |  -8.236 |
# | ave_unit_sqft                  |    -0.672   |   0.063    | -10.652 |
# | ave_lot_sqft                   |    0.210    |   0.045    |  4.664  |
# | ave_income                     |    0.911    |   0.055    |  16.611 |
# | hhsize                         |    -3.000   |   0.273    | -10.976 |
# | jobs                           |    0.536    |   0.018    |  29.054 |
# | poor                           |    0.069    |   0.068    |  1.020  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 61
#
# Null Log-liklihood: -28510.609
# Log-liklihood at convergence: -26015.765
# Log-liklihood Ratio: 0.088
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.696    |   0.062    |  11.133 |
# | np.log1p(stories)              |    0.932    |   0.026    |  36.461 |
# | sum_residential_units          |    -0.232   |   0.116    |  -1.996 |
# | ave_unit_sqft                  |    -0.052   |   0.062    |  -0.845 |
# | ave_lot_sqft                   |    -0.279   |   0.026    | -10.780 |
# | ave_income                     |    -0.478   |   0.074    |  -6.494 |
# | hhsize                         |    0.315    |   0.316    |  0.996  |
# | jobs                           |    0.164    |   0.023    |  7.135  |
# | poor                           |    0.177    |   0.087    |  2.048  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 62
#
# Null Log-liklihood: -33907.868
# Log-liklihood at convergence: -31246.627
# Log-liklihood Ratio: 0.078
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.244   |   0.048    |  -5.085 |
# | np.log1p(stories)              |    0.988    |   0.021    |  46.301 |
# | sum_residential_units          |    0.171    |   0.111    |  1.543  |
# | ave_unit_sqft                  |    2.544    |   0.070    |  36.299 |
# | ave_lot_sqft                   |    -1.668   |   0.042    | -39.897 |
# | ave_income                     |    0.526    |   0.061    |  8.593  |
# | hhsize                         |    -0.977   |   0.271    |  -3.602 |
# | jobs                           |    0.272    |   0.021    |  12.894 |
# | poor                           |    0.025    |   0.076    |  0.334  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 71
#
# Null Log-liklihood: -33392.089
# Log-liklihood at convergence: -30370.465
# Log-liklihood Ratio: 0.090
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.985    |   0.045    |  21.872 |
# | np.log1p(stories)              |    0.172    |   0.022    |  7.880  |
# | sum_residential_units          |    -0.675   |   0.101    |  -6.672 |
# | ave_unit_sqft                  |    0.377    |   0.095    |  3.954  |
# | ave_lot_sqft                   |    0.136    |   0.073    |  1.869  |
# | ave_income                     |    -0.066   |   0.047    |  -1.399 |
# | hhsize                         |    -3.000   |   0.242    | -12.373 |
# | jobs                           |    0.389    |   0.027    |  14.450 |
# | poor                           |    0.373    |   0.068    |  5.484  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 72
#
# Null Log-liklihood: -40502.472
# Log-liklihood at convergence: -35772.807
# Log-liklihood Ratio: 0.117
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.148    |   0.052    |  22.125 |
# | np.log1p(stories)              |    0.294    |   0.020    |  14.424 |
# | sum_residential_units          |    -0.565   |   0.100    |  -5.659 |
# | ave_unit_sqft                  |    -0.179   |   0.074    |  -2.408 |
# | ave_lot_sqft                   |    -0.259   |   0.056    |  -4.600 |
# | ave_income                     |    0.139    |   0.047    |  2.936  |
# | hhsize                         |    -3.000   |   0.233    | -12.900 |
# | jobs                           |    0.511    |   0.021    |  24.610 |
# | poor                           |    0.143    |   0.069    |  2.066  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 81
#
# Null Log-liklihood: -43122.814
# Log-liklihood at convergence: -39811.113
# Log-liklihood Ratio: 0.077
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.130    |   0.040    |  3.229  |
# | np.log1p(stories)              |    0.587    |   0.019    |  31.110 |
# | sum_residential_units          |    -0.020   |   0.081    |  -0.250 |
# | ave_unit_sqft                  |    -0.397   |   0.046    |  -8.708 |
# | ave_lot_sqft                   |    0.088    |   0.022    |  3.963  |
# | ave_income                     |    -0.021   |   0.051    |  -0.418 |
# | hhsize                         |    -0.024   |   0.229    |  -0.104 |
# | jobs                           |    0.406    |   0.016    |  25.079 |
# | poor                           |    -0.134   |   0.059    |  -2.257 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 92
#
# Null Log-liklihood: -40345.896
# Log-liklihood at convergence: -30035.652
# Log-liklihood Ratio: 0.256
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.780    |   0.053    |  14.792 |
# | np.log1p(stories)              |    1.209    |   0.019    |  62.204 |
# | sum_residential_units          |    -1.833   |   0.156    | -11.713 |
# | ave_unit_sqft                  |    1.906    |   0.096    |  19.916 |
# | ave_lot_sqft                   |    0.136    |   0.079    |  1.714  |
# | ave_income                     |    -1.183   |   0.094    | -12.614 |
# | hhsize                         |    -3.000   |   0.489    |  -6.130 |
# | jobs                           |    0.222    |   0.028    |  7.812  |
# | poor                           |    1.583    |   0.104    |  15.196 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 99
#
# Null Log-liklihood: -3665.715
# Log-liklihood at convergence: -2635.777
# Log-liklihood Ratio: 0.281
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.424    |   0.273    |  1.553  |
# | np.log1p(stories)              |    0.741    |   0.075    |  9.930  |
# | sum_residential_units          |    1.214    |   0.572    |  2.122  |
# | ave_unit_sqft                  |    0.878    |   0.393    |  2.233  |
# | ave_lot_sqft                   |    -1.672   |   0.294    |  -5.685 |
# | ave_income                     |    -1.299   |   0.287    |  -4.530 |
# | hhsize                         |    -1.449   |   1.731    |  -0.837 |
# | jobs                           |    0.940    |   0.084    |  11.202 |
# | poor                           |    -1.594   |   0.389    |  -4.095 |
# +--------------------------------+-------------+------------+---------+
# Time to execute model 'elcm_estimate': 96.32s
# Total time to execute: 96.32s
