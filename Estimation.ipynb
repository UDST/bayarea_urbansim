# %%
# %load_ext autoreload
# %autoreload 2
import models
import urbansim.sim.simulation as sim

# %%
sim.run(["build_networks"])
# Out:
# Running model 'build_networks'

# %%
sim.run(["neighborhood_vars"])
# Out:
# Running model 'neighborhood_vars'
# Computing accessibility variables
# Computing sum_residential_units
#     Fields available to accvar = residential_units, _node_id0
#     dataframe = buildings, varname=residential_units
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing sum_nonresidential_units
#     Fields available to accvar = job_spaces, _node_id0
#     dataframe = buildings, varname=job_spaces
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing ave_unit_sqft
#     Fields available to accvar = unit_sqft, general_type, _node_id0
#     Filters = ['general_type == "Residential"']
#     dataframe = buildings, varname=unit_sqft
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Computing ave_lot_sqft
#     Fields available to accvar = unit_lot_size, _node_id0
#     dataframe = buildings, varname=unit_lot_size
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Computing population
#     Fields available to accvar = persons, _node_id0
#     dataframe = households, varname=persons
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing poor
#     Fields available to accvar = persons, income, _node_id0
#     Filters = ['income < 40000']
#     dataframe = households, varname=persons
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing renters
#     Fields available to accvar = tenure, _node_id0
#     Filters = ['tenure == 2']
#     dataframe = households, varname=None
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing sfdu
#     Fields available to accvar = building_type_id, _node_id0
#     Filters = ['building_type_id == 1']
#     dataframe = buildings, varname=None
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing hhsize
#     Fields available to accvar = persons, _node_id0
#     dataframe = households, varname=persons
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Computing jobs
#     Fields available to accvar = _node_id0
#     dataframe = jobs, varname=None
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing ave_income
#     Fields available to accvar = income, _node_id0
#     dataframe = households, varname=income
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Done

# %% [markdown]
# ## Hedonic Estimation

# %%
sim.run(["rsh_estimate"])
# Out:
# Running model 'rsh_estimate'
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     np.log1p(sale_price_flt)   R-squared:                       0.217
# Model:                                  OLS   Adj. R-squared:                  0.216
# Method:                       Least Squares   F-statistic:                     302.7
# Date:                      Mon, 04 Aug 2014   Prob (F-statistic):               0.00
# Time:                              13:49:30   Log-Likelihood:                -4992.8
# No. Observations:                      8738   AIC:                         1.000e+04
# Df Residuals:                          8729   BIC:                         1.007e+04
# Df Model:                                 8
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        8.6208      0.113     76.353      0.000         8.399     8.842
# I(year_built < 1940)[T.True]     0.0436      0.010      4.357      0.000         0.024     0.063
# I(year_built > 2005)[T.True]     0.0713      0.076      0.932      0.351        -0.079     0.221
# np.log1p(unit_sqft)             -0.4346      0.010    -44.067      0.000        -0.454    -0.415
# np.log1p(unit_lot_size)          0.0634      0.007      8.871      0.000         0.049     0.077
# sum_residential_units            0.0837      0.007     12.529      0.000         0.071     0.097
# ave_unit_sqft                   -0.0016      0.026     -0.060      0.952        -0.053     0.050
# ave_lot_sqft                    -0.2809      0.016    -17.135      0.000        -0.313    -0.249
# ave_income                       0.1621      0.014     11.254      0.000         0.134     0.190
# ==============================================================================
# Omnibus:                      867.822   Durbin-Watson:                   1.324
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2405.219
# Skew:                          -0.551   Prob(JB):                         0.00
# Kurtosis:                       5.322   Cond. No.                         515.
# ==============================================================================

# %%
sim.run(["rrh_estimate"])
# Out:
# Running model 'rrh_estimate'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Mon, 04 Aug 2014   Prob (F-statistic):           1.64e-17
# Time:                        13:49:30   Log-Likelihood:                 95.640
# No. Observations:                 178   AIC:                            -179.3
# Df Residuals:                     172   BIC:                            -160.2
# Df Model:                           5
# =========================================================================================
#                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# Intercept                 2.5404      0.382      6.652      0.000         1.787     3.294
# np.log1p(unit_sqft)      -0.1953      0.030     -6.471      0.000        -0.255    -0.136
# sum_residential_units    -0.0268      0.024     -1.110      0.268        -0.074     0.021
# ave_unit_sqft             0.0006      0.015      0.042      0.967        -0.028     0.030
# ave_lot_sqft             -0.0365      0.027     -1.336      0.183        -0.090     0.017
# jobs                      0.0752      0.015      5.049      0.000         0.046     0.105
# ==============================================================================
# Omnibus:                       11.211   Durbin-Watson:                   1.302
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               27.319
# Skew:                          -0.030   Prob(JB):                     1.17e-06
# Kurtosis:                       4.918   Cond. No.                         662.
# ==============================================================================

# %%
sim.run(["nrh_estimate"])
# Out:
# Running model 'nrh_estimate'
# REGRESSION RESULTS FOR SEGMENT Retail
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.316
# Date:                Mon, 04 Aug 2014   Prob (F-statistic):              0.262
# Time:                        13:49:31   Log-Likelihood:                -73.855
# No. Observations:                 124   AIC:                             159.7
# Df Residuals:                     118   BIC:                             176.6
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.8609      2.476     -0.348      0.729        -5.765     4.043
# I(year_built < 1940)[T.True]    -0.0941      0.105     -0.896      0.372        -0.302     0.114
# I(year_built > 2005)[T.True]    -0.1046      0.246     -0.426      0.671        -0.591     0.382
# np.log1p(stories)               -0.0755      0.110     -0.684      0.495        -0.294     0.143
# ave_income                       0.2976      0.193      1.545      0.125        -0.084     0.679
# jobs                             0.1151      0.046      2.482      0.014         0.023     0.207
# ==============================================================================
# Omnibus:                       15.597   Durbin-Watson:                   2.433
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.800
# Skew:                           0.492   Prob(JB):                     1.24e-07
# Kurtosis:                       5.277   Cond. No.                         910.
# ==============================================================================
# REGRESSION RESULTS FOR SEGMENT Office
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     3.490
# Date:                Mon, 04 Aug 2014   Prob (F-statistic):            0.00426
# Time:                        13:49:31   Log-Likelihood:                -168.79
# No. Observations:                 385   AIC:                             349.6
# Df Residuals:                     379   BIC:                             373.3
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.5244      0.207     17.017      0.000         3.117     3.932
# I(year_built < 1940)[T.True]    -0.0787      0.046     -1.698      0.090        -0.170     0.012
# I(year_built > 2005)[T.True]    -0.0188      0.173     -0.109      0.913        -0.358     0.321
# np.log1p(stories)                0.0493      0.035      1.401      0.162        -0.020     0.118
# ave_income                      -0.0417      0.023     -1.831      0.068        -0.086     0.003
# jobs                             0.0194      0.018      1.079      0.281        -0.016     0.055
# ==============================================================================
# Omnibus:                      106.606   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              544.913
# Skew:                           1.074   Prob(JB):                    4.72e-119
# Kurtosis:                       8.418   Cond. No.                         167.
# ==============================================================================
# REGRESSION RESULTS FOR SEGMENT Industrial
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     931.2
# Date:                Mon, 04 Aug 2014   Prob (F-statistic):           1.19e-66
# Time:                        13:49:31   Log-Likelihood:                -21.284
# No. Observations:                  81   AIC:                             52.57
# Df Residuals:                      76   BIC:                             64.54
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.5185      0.347      7.266      0.000         1.828     3.209
# I(year_built < 1940)[T.True]     0.0130      0.083      0.157      0.876        -0.152     0.178
# I(year_built > 2005)[T.True] -9.623e-17   1.68e-16     -0.573      0.568     -4.31e-16  2.38e-16
# np.log1p(stories)                0.0788      0.134      0.588      0.558        -0.188     0.346
# ave_income                      -0.0388      0.039     -0.994      0.323        -0.116     0.039
# jobs                             0.0338      0.035      0.956      0.342        -0.037     0.104
# ==============================================================================
# Omnibus:                        8.537   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               18.123
# Skew:                           0.117   Prob(JB):                     0.000116
# Kurtosis:                       5.305   Cond. No.                     6.08e+09
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is 4.44e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Hedonic Simulation

# %%
sim.run(["rsh_simulate", "rrh_simulate", "nrh_simulate"])
# Out:
# Running model 'rsh_simulate'
# Dropped 3118 rows because they contained nans
# count    138407.000000
# mean        543.457014
# std         171.494620
# min          14.502545
# 25%         461.634613
# 50%         528.977634
# 75%         596.176894
# max       10138.582062
# dtype: float64
# Running model 'rrh_simulate'
# Dropped 2 rows because they contained nans
# count    140780.000000
# mean          3.412905
# std           0.499166
# min           0.630713
# 25%           3.151931
# 50%           3.343975
# 75%           3.580759
# max          15.340111
# dtype: float64
# Running model 'nrh_simulate'
# Dropped 3118 rows because they contained nans
# count    10203.000000
# mean        23.982738
# std          7.233765
# min          0.480017
# 25%         22.415323
# 50%         26.249629
# 75%         28.755369
# max         40.735691
# dtype: float64

# %% [markdown]
# ## LCM Estimation

# %%
sim.run(["hlcmo_estimate"])
# Out:
# Running model 'hlcmo_estimate'
# Dropped 14198 rows because they contained nans
# LCM RESULTS FOR SEGMENT 0
# Null Log-liklihood: -65540.782
# Log-liklihood at convergence: -64538.480
# Log-liklihood Ratio: 0.015
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -1.813   |   0.158    | -11.458 |
# | np.log1p(unit_sqft)               |    -0.878   |   0.065    | -13.562 |
# | sum_residential_units             |    -1.712   |   0.071    | -24.273 |
# | ave_unit_sqft                     |    0.153    |   0.059    |  2.588  |
# | ave_lot_sqft                      |    -0.440   |   0.053    |  -8.377 |
# | ave_income                        |    -1.307   |   0.146    |  -8.967 |
# | hhsize                            |    -3.000   |   0.142    | -21.189 |
# | jobs                              |    0.134    |   0.020    |  6.564  |
# | poor                              |    -0.166   |   0.079    |  -2.101 |
# | population                        |    1.995    |   0.072    |  27.624 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -67926.260
# Log-liklihood at convergence: -67352.881
# Log-liklihood Ratio: 0.008
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -2.426   |   0.151    | -16.076 |
# | np.log1p(unit_sqft)               |    -1.171   |   0.062    | -18.862 |
# | sum_residential_units             |    -1.119   |   0.070    | -16.000 |
# | ave_unit_sqft                     |    0.148    |   0.056    |  2.633  |
# | ave_lot_sqft                      |    -0.721   |   0.052    | -13.916 |
# | ave_income                        |    -0.291   |   0.141    |  -2.067 |
# | hhsize                            |    -2.339   |   0.142    | -16.451 |
# | jobs                              |    0.114    |   0.020    |  5.604  |
# | poor                              |    -0.079   |   0.077    |  -1.028 |
# | population                        |    1.353    |   0.072    |  18.878 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -67990.733
# Log-liklihood at convergence: -67445.162
# Log-liklihood Ratio: 0.008
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -2.699   |   0.153    | -17.586 |
# | np.log1p(unit_sqft)               |    -1.315   |   0.062    | -21.117 |
# | sum_residential_units             |    -0.983   |   0.070    | -14.113 |
# | ave_unit_sqft                     |    0.060    |   0.056    |  1.070  |
# | ave_lot_sqft                      |    -0.688   |   0.053    | -13.110 |
# | ave_income                        |    -0.289   |   0.144    |  -2.003 |
# | hhsize                            |    -2.002   |   0.143    | -14.012 |
# | jobs                              |    0.123    |   0.020    |  6.085  |
# | poor                              |    -0.498   |   0.078    |  -6.346 |
# | population                        |    1.629    |   0.074    |  22.036 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -68220.991
# Log-liklihood at convergence: -67181.828
# Log-liklihood Ratio: 0.015
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -3.000   |   0.145    | -20.682 |
# | np.log1p(unit_sqft)               |    -1.474   |   0.059    | -24.924 |
# | sum_residential_units             |    -1.088   |   0.068    | -16.016 |
# | ave_unit_sqft                     |    0.244    |   0.057    |  4.263  |
# | ave_lot_sqft                      |    -0.814   |   0.052    | -15.565 |
# | ave_income                        |    1.054    |   0.138    |  7.627  |
# | hhsize                            |    -3.000   |   0.145    | -20.757 |
# | jobs                              |    0.201    |   0.020    |  9.796  |
# | poor                              |    -0.328   |   0.077    |  -4.279 |
# | population                        |    1.519    |   0.071    |  21.368 |
# +-----------------------------------+-------------+------------+---------+

# %%
sim.run(["hlcmr_estimate"])
# Out:
# Running model 'hlcmr_estimate'
# Dropped 11825 rows because they contained nans
# LCM RESULTS FOR SEGMENT 0
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -18233.270
# Log-liklihood Ratio: 0.208
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.819    |  -3.663 |
# | np.log1p(unit_sqft)        |    -0.909   |   0.133    |  -6.819 |
# | sum_residential_units      |    -0.322   |   0.129    |  -2.502 |
# | ave_unit_sqft              |    -0.036   |   0.106    |  -0.341 |
# | ave_lot_sqft               |    0.712    |   0.053    |  13.497 |
# | ave_income                 |    -1.051   |   0.134    |  -7.835 |
# | hhsize                     |    -3.000   |   0.274    | -10.957 |
# | jobs                       |    0.321    |   0.060    |  5.341  |
# | poor                       |    0.846    |   0.097    |  8.703  |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20099.998
# Log-liklihood Ratio: 0.127
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.798    |  -3.761 |
# | np.log1p(unit_sqft)        |    -1.030   |   0.131    |  -7.866 |
# | sum_residential_units      |    0.239    |   0.127    |  1.878  |
# | ave_unit_sqft              |    -0.190   |   0.104    |  -1.825 |
# | ave_lot_sqft               |    0.412    |   0.046    |  8.904  |
# | ave_income                 |    -0.813   |   0.133    |  -6.108 |
# | hhsize                     |    -3.000   |   0.272    | -11.022 |
# | jobs                       |    0.086    |   0.059    |  1.459  |
# | poor                       |    0.312    |   0.096    |  3.246  |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20684.476
# Log-liklihood Ratio: 0.102
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.723    |  -4.147 |
# | np.log1p(unit_sqft)        |    -1.151   |   0.119    |  -9.651 |
# | sum_residential_units      |    0.612    |   0.121    |  5.059  |
# | ave_unit_sqft              |    -0.330   |   0.104    |  -3.186 |
# | ave_lot_sqft               |    0.194    |   0.048    |  4.045  |
# | ave_income                 |    -0.122   |   0.129    |  -0.949 |
# | hhsize                     |    -3.000   |   0.268    | -11.188 |
# | jobs                       |    0.111    |   0.054    |  2.069  |
# | poor                       |    -0.276   |   0.090    |  -3.070 |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20552.425
# Log-liklihood Ratio: 0.107
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.697    |  -4.303 |
# | np.log1p(unit_sqft)        |    -1.198   |   0.116    | -10.366 |
# | sum_residential_units      |    0.656    |   0.125    |  5.267  |
# | ave_unit_sqft              |    -0.363   |   0.103    |  -3.541 |
# | ave_lot_sqft               |    0.082    |   0.056    |  1.480  |
# | ave_income                 |    1.008    |   0.128    |  7.850  |
# | hhsize                     |    -3.000   |   0.285    | -10.512 |
# | jobs                       |    0.271    |   0.054    |  5.020  |
# | poor                       |    -0.523   |   0.094    |  -5.561 |
# +----------------------------+-------------+------------+---------+

# %%
sim.run(["elcm_estimate"])
# Out:
# Running model 'elcm_estimate'
# Dropped 142402 rows because they contained nans
# LCM RESULTS FOR SEGMENT 11
# Null Log-liklihood: -2256.533
# Log-liklihood at convergence: -1741.778
# Log-liklihood Ratio: 0.228
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.923    |   0.256    |  3.610  |
# | np.log1p(stories)              |    0.494    |   0.082    |  6.027  |
# | sum_residential_units          |    -1.214   |   0.470    |  -2.584 |
# | ave_unit_sqft                  |    1.581    |   0.302    |  5.238  |
# | ave_lot_sqft                   |    -2.293   |   0.243    |  -9.425 |
# | ave_income                     |    -1.165   |   0.257    |  -4.540 |
# | hhsize                         |    -3.000   |   1.273    |  -2.357 |
# | jobs                           |    1.120    |   0.084    |  13.302 |
# | poor                           |    -0.440   |   0.329    |  -1.339 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 21
#
# Null Log-liklihood: -515.779
# Log-liklihood at convergence: -198.068
# Log-liklihood Ratio: 0.616
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.713    |   1.533    |  0.465  |
# | np.log1p(stories)              |    0.344    |   0.223    |  1.544  |
# | sum_residential_units          |    -0.185   |   3.402    |  -0.054 |
# | ave_unit_sqft                  |    -3.000   |   1.913    |  -1.568 |
# | ave_lot_sqft                   |    3.000    |   1.344    |  2.233  |
# | ave_income                     |    3.000    |   1.397    |  2.147  |
# | hhsize                         |    3.000    |   7.240    |  0.414  |
# | jobs                           |    2.454    |   0.585    |  4.192  |
# | poor                           |    -0.473   |   2.403    |  -0.197 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 22
#
# Null Log-liklihood: -22183.105
# Log-liklihood at convergence: -3349.016
# Log-liklihood Ratio: 0.849
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    3.000    |   0.162    |  18.464 |
# | np.log1p(stories)              |    -1.652   |   0.051    | -32.597 |
# | sum_residential_units          |    -0.196   |   0.333    |  -0.591 |
# | ave_unit_sqft                  |    -2.477   |   0.176    | -14.103 |
# | ave_lot_sqft                   |    2.767    |   0.069    |  40.108 |
# | ave_income                     |    1.473    |   0.184    |  8.019  |
# | hhsize                         |    3.000    |   0.979    |  3.064  |
# | jobs                           |    2.849    |   0.084    |  33.786 |
# | poor                           |    -1.030   |   0.230    |  -4.475 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 23
#
# Null Log-liklihood: -44974.092
# Log-liklihood at convergence: -41189.312
# Log-liklihood Ratio: 0.084
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.554   |   0.035    | -15.657 |
# | np.log1p(stories)              |    0.792    |   0.021    |  38.235 |
# | sum_residential_units          |    -0.817   |   0.063    | -12.975 |
# | ave_unit_sqft                  |    0.320    |   0.047    |  6.854  |
# | ave_lot_sqft                   |    0.742    |   0.032    |  23.355 |
# | ave_income                     |    1.701    |   0.043    |  39.455 |
# | hhsize                         |    1.703    |   0.181    |  9.419  |
# | jobs                           |    0.563    |   0.016    |  34.124 |
# | poor                           |    0.558    |   0.046    |  12.016 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 31
#
# Null Log-liklihood: -29905.975
# Log-liklihood at convergence: -24814.356
# Log-liklihood Ratio: 0.170
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.555    |   0.053    |  10.523 |
# | np.log1p(stories)              |    -0.217   |   0.032    |  -6.772 |
# | sum_residential_units          |    -2.383   |   0.096    | -24.936 |
# | ave_unit_sqft                  |    0.263    |   0.109    |  2.418  |
# | ave_lot_sqft                   |    -1.425   |   0.092    | -15.525 |
# | ave_income                     |    0.392    |   0.052    |  7.569  |
# | hhsize                         |    -3.000   |   0.237    | -12.637 |
# | jobs                           |    1.348    |   0.030    |  45.108 |
# | poor                           |    0.298    |   0.070    |  4.290  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 32
#
# Null Log-liklihood: -18158.186
# Log-liklihood at convergence: -15771.047
# Log-liklihood Ratio: 0.131
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.391   |   0.068    |  -5.758 |
# | np.log1p(stories)              |    0.543    |   0.032    |  16.988 |
# | sum_residential_units          |    -3.000   |   0.102    | -29.371 |
# | ave_unit_sqft                  |    1.828    |   0.098    |  18.678 |
# | ave_lot_sqft                   |    0.169    |   0.075    |  2.238  |
# | ave_income                     |    3.000    |   0.083    |  36.325 |
# | hhsize                         |    0.998    |   0.360    |  2.769  |
# | jobs                           |    1.327    |   0.031    |  42.943 |
# | poor                           |    2.139    |   0.077    |  27.866 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 33
#
# Null Log-liklihood: -19682.497
# Log-liklihood at convergence: -18150.055
# Log-liklihood Ratio: 0.078
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.633   |   0.059    | -10.805 |
# | np.log1p(stories)              |    0.469    |   0.032    |  14.518 |
# | sum_residential_units          |    -1.464   |   0.117    | -12.479 |
# | ave_unit_sqft                  |    0.617    |   0.123    |  5.007  |
# | ave_lot_sqft                   |    0.006    |   0.099    |  0.058  |
# | ave_income                     |    1.707    |   0.072    |  23.850 |
# | hhsize                         |    0.390    |   0.315    |  1.240  |
# | jobs                           |    0.913    |   0.032    |  28.450 |
# | poor                           |    0.822    |   0.083    |  9.932  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 42
#
# Null Log-liklihood: -50841.079
# Log-liklihood at convergence: -40435.064
# Log-liklihood Ratio: 0.205
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.026   |   0.036    |  -0.740 |
# | np.log1p(stories)              |    0.848    |   0.016    |  53.956 |
# | sum_residential_units          |    -0.938   |   0.068    | -13.788 |
# | ave_unit_sqft                  |    -0.583   |   0.047    | -12.414 |
# | ave_lot_sqft                   |    0.705    |   0.028    |  24.795 |
# | ave_income                     |    0.575    |   0.046    |  12.632 |
# | hhsize                         |    0.675    |   0.197    |  3.431  |
# | jobs                           |    0.768    |   0.016    |  47.954 |
# | poor                           |    0.123    |   0.048    |  2.568  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 44
#
# Null Log-liklihood: -42505.721
# Log-liklihood at convergence: -38161.321
# Log-liklihood Ratio: 0.102
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.967    |   0.044    |  22.017 |
# | np.log1p(stories)              |    0.695    |   0.021    |  33.640 |
# | sum_residential_units          |    -0.245   |   0.089    |  -2.753 |
# | ave_unit_sqft                  |    0.398    |   0.064    |  6.208  |
# | ave_lot_sqft                   |    0.013    |   0.043    |  0.295  |
# | ave_income                     |    0.674    |   0.049    |  13.691 |
# | hhsize                         |    -1.081   |   0.224    |  -4.826 |
# | jobs                           |    0.349    |   0.021    |  16.887 |
# | poor                           |    -0.212   |   0.063    |  -3.387 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 45
#
# Null Log-liklihood: -36302.557
# Log-liklihood at convergence: -33156.924
# Log-liklihood Ratio: 0.087
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.189    |   0.052    |  22.999 |
# | np.log1p(stories)              |    0.433    |   0.022    |  19.673 |
# | sum_residential_units          |    -0.466   |   0.089    |  -5.237 |
# | ave_unit_sqft                  |    0.567    |   0.082    |  6.945  |
# | ave_lot_sqft                   |    -0.007   |   0.062    |  -0.108 |
# | ave_income                     |    -0.206   |   0.047    |  -4.402 |
# | hhsize                         |    -3.000   |   0.233    | -12.852 |
# | jobs                           |    0.200    |   0.023    |  8.704  |
# | poor                           |    0.199    |   0.060    |  3.312  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 48
#
# Null Log-liklihood: -20502.218
# Log-liklihood at convergence: -15376.207
# Log-liklihood Ratio: 0.250
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.096    |   0.066    |  1.452  |
# | np.log1p(stories)              |    0.418    |   0.026    |  16.066 |
# | sum_residential_units          |    -2.293   |   0.095    | -24.246 |
# | ave_unit_sqft                  |    0.344    |   0.089    |  3.877  |
# | ave_lot_sqft                   |    -0.381   |   0.068    |  -5.617 |
# | ave_income                     |    0.673    |   0.060    |  11.139 |
# | hhsize                         |    -3.000   |   0.237    | -12.659 |
# | jobs                           |    1.014    |   0.021    |  48.659 |
# | poor                           |    0.377    |   0.068    |  5.564  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 49
#
# Null Log-liklihood: -12130.018
# Log-liklihood at convergence: -9287.381
# Log-liklihood Ratio: 0.234
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.374   |   0.110    |  -3.402 |
# | np.log1p(stories)              |    -0.056   |   0.085    |  -0.665 |
# | sum_residential_units          |    -2.950   |   0.114    | -25.900 |
# | ave_unit_sqft                  |    -0.159   |   0.145    |  -1.090 |
# | ave_lot_sqft                   |    0.739    |   0.057    |  12.895 |
# | ave_income                     |    0.025    |   0.144    |  0.172  |
# | hhsize                         |    3.000    |   0.513    |  5.847  |
# | jobs                           |    0.617    |   0.040    |  15.324 |
# | poor                           |    2.057    |   0.063    |  32.475 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 51
#
# Null Log-liklihood: -48625.992
# Log-liklihood at convergence: -36253.592
# Log-liklihood Ratio: 0.254
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.309   |   0.036    |  -8.505 |
# | np.log1p(stories)              |    0.277    |   0.016    |  17.517 |
# | sum_residential_units          |    -0.415   |   0.084    |  -4.937 |
# | ave_unit_sqft                  |    0.488    |   0.073    |  6.692  |
# | ave_lot_sqft                   |    -0.701   |   0.055    | -12.649 |
# | ave_income                     |    -0.139   |   0.047    |  -2.977 |
# | hhsize                         |    -3.000   |   0.256    | -11.715 |
# | jobs                           |    1.149    |   0.019    |  61.863 |
# | poor                           |    -0.737   |   0.060    | -12.227 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 52
#
# Null Log-liklihood: -53829.834
# Log-liklihood at convergence: -25099.361
# Log-liklihood Ratio: 0.534
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.823    |   0.085    |  9.705  |
# | np.log1p(stories)              |    1.033    |   0.016    |  65.828 |
# | sum_residential_units          |    -1.554   |   0.133    | -11.715 |
# | ave_unit_sqft                  |    -2.070   |   0.106    | -19.523 |
# | ave_lot_sqft                   |    0.972    |   0.089    |  10.952 |
# | ave_income                     |    3.000    |   0.070    |  42.864 |
# | hhsize                         |    -3.000   |   0.392    |  -7.660 |
# | jobs                           |    1.425    |   0.032    |  44.757 |
# | poor                           |    0.418    |   0.094    |  4.430  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 53
#
# Null Log-liklihood: -37214.380
# Log-liklihood at convergence: -31786.323
# Log-liklihood Ratio: 0.146
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.281    |   0.055    |  5.142  |
# | np.log1p(stories)              |    0.851    |   0.019    |  43.884 |
# | sum_residential_units          |    0.034    |   0.090    |  0.385  |
# | ave_unit_sqft                  |    -1.299   |   0.054    | -24.188 |
# | ave_lot_sqft                   |    0.142    |   0.034    |  4.184  |
# | ave_income                     |    1.101    |   0.054    |  20.389 |
# | hhsize                         |    -3.000   |   0.272    | -11.047 |
# | jobs                           |    0.337    |   0.018    |  18.969 |
# | poor                           |    -0.421   |   0.067    |  -6.296 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 54
#
# Null Log-liklihood: -55648.877
# Log-liklihood at convergence: -34207.698
# Log-liklihood Ratio: 0.385
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.172    |   0.046    |  3.720  |
# | np.log1p(stories)              |    0.773    |   0.013    |  59.033 |
# | sum_residential_units          |    -0.692   |   0.093    |  -7.481 |
# | ave_unit_sqft                  |    -1.443   |   0.077    | -18.840 |
# | ave_lot_sqft                   |    0.994    |   0.063    |  15.817 |
# | ave_income                     |    1.535    |   0.053    |  28.838 |
# | hhsize                         |    -3.000   |   0.289    | -10.396 |
# | jobs                           |    1.072    |   0.021    |  50.322 |
# | poor                           |    -0.116   |   0.066    |  -1.749 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 55
#
# Null Log-liklihood: -5705.806
# Log-liklihood at convergence: -3306.301
# Log-liklihood Ratio: 0.421
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.682    |   0.189    |  3.613  |
# | np.log1p(stories)              |    0.846    |   0.043    |  19.702 |
# | sum_residential_units          |    -1.675   |   0.383    |  -4.374 |
# | ave_unit_sqft                  |    -1.109   |   0.319    |  -3.478 |
# | ave_lot_sqft                   |    0.128    |   0.256    |  0.502  |
# | ave_income                     |    3.000    |   0.200    |  14.965 |
# | hhsize                         |    -1.911   |   1.066    |  -1.792 |
# | jobs                           |    1.480    |   0.076    |  19.374 |
# | poor                           |    0.585    |   0.274    |  2.132  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 56
#
# Null Log-liklihood: -38476.197
# Log-liklihood at convergence: -32782.244
# Log-liklihood Ratio: 0.148
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.413    |   0.042    |  9.729  |
# | np.log1p(stories)              |    0.661    |   0.018    |  37.702 |
# | sum_residential_units          |    -0.743   |   0.089    |  -8.308 |
# | ave_unit_sqft                  |    -0.795   |   0.054    | -14.660 |
# | ave_lot_sqft                   |    0.308    |   0.034    |  8.949  |
# | ave_income                     |    0.961    |   0.054    |  17.921 |
# | hhsize                         |    -3.000   |   0.267    | -11.243 |
# | jobs                           |    0.532    |   0.017    |  30.720 |
# | poor                           |    0.057    |   0.066    |  0.865  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 61
#
# Null Log-liklihood: -28920.469
# Log-liklihood at convergence: -26404.582
# Log-liklihood Ratio: 0.087
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.742    |   0.062    |  12.048 |
# | np.log1p(stories)              |    0.929    |   0.025    |  36.674 |
# | sum_residential_units          |    -0.174   |   0.116    |  -1.496 |
# | ave_unit_sqft                  |    -0.045   |   0.061    |  -0.728 |
# | ave_lot_sqft                   |    -0.277   |   0.025    | -11.075 |
# | ave_income                     |    -0.501   |   0.073    |  -6.857 |
# | hhsize                         |    0.364    |   0.317    |  1.150  |
# | jobs                           |    0.159    |   0.023    |  6.978  |
# | poor                           |    0.120    |   0.087    |  1.383  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 62
#
# Null Log-liklihood: -34133.521
# Log-liklihood at convergence: -31625.022
# Log-liklihood Ratio: 0.073
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.249   |   0.049    |  -5.108 |
# | np.log1p(stories)              |    0.905    |   0.021    |  42.171 |
# | sum_residential_units          |    0.189    |   0.116    |  1.629  |
# | ave_unit_sqft                  |    2.499    |   0.083    |  30.124 |
# | ave_lot_sqft                   |    -1.600   |   0.054    | -29.364 |
# | ave_income                     |    0.694    |   0.061    |  11.413 |
# | hhsize                         |    -0.657   |   0.267    |  -2.459 |
# | jobs                           |    0.333    |   0.023    |  14.544 |
# | poor                           |    0.040    |   0.078    |  0.518  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 71
#
# Null Log-liklihood: -33392.089
# Log-liklihood at convergence: -30376.576
# Log-liklihood Ratio: 0.090
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.988    |   0.045    |  21.930 |
# | np.log1p(stories)              |    0.177    |   0.022    |  8.093  |
# | sum_residential_units          |    -0.681   |   0.101    |  -6.724 |
# | ave_unit_sqft                  |    0.399    |   0.096    |  4.175  |
# | ave_lot_sqft                   |    0.124    |   0.073    |  1.693  |
# | ave_income                     |    -0.080   |   0.047    |  -1.715 |
# | hhsize                         |    -3.000   |   0.242    | -12.373 |
# | jobs                           |    0.385    |   0.027    |  14.295 |
# | poor                           |    0.381    |   0.068    |  5.592  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 72
#
# Null Log-liklihood: -40359.712
# Log-liklihood at convergence: -35792.430
# Log-liklihood Ratio: 0.113
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.092    |   0.051    |  21.288 |
# | np.log1p(stories)              |    0.297    |   0.021    |  14.483 |
# | sum_residential_units          |    -0.596   |   0.104    |  -5.741 |
# | ave_unit_sqft                  |    -0.168   |   0.081    |  -2.062 |
# | ave_lot_sqft                   |    -0.285   |   0.064    |  -4.455 |
# | ave_income                     |    0.185    |   0.048    |  3.862  |
# | hhsize                         |    -3.000   |   0.232    | -12.919 |
# | jobs                           |    0.518    |   0.022    |  23.191 |
# | poor                           |    0.142    |   0.072    |  1.980  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 81
#
# Null Log-liklihood: -43385.308
# Log-liklihood at convergence: -40127.511
# Log-liklihood Ratio: 0.075
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.169    |   0.040    |  4.208  |
# | np.log1p(stories)              |    0.563    |   0.019    |  29.901 |
# | sum_residential_units          |    0.044    |   0.084    |  0.530  |
# | ave_unit_sqft                  |    -0.372   |   0.047    |  -7.970 |
# | ave_lot_sqft                   |    0.048    |   0.024    |  1.944  |
# | ave_income                     |    -0.062   |   0.051    |  -1.221 |
# | hhsize                         |    0.077    |   0.234    |  0.327  |
# | jobs                           |    0.408    |   0.016    |  24.878 |
# | poor                           |    -0.183   |   0.061    |  -2.998 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 92
#
# Null Log-liklihood: -40212.346
# Log-liklihood at convergence: -29947.913
# Log-liklihood Ratio: 0.255
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.848    |   0.053    |  16.100 |
# | np.log1p(stories)              |    1.180    |   0.019    |  61.532 |
# | sum_residential_units          |    -1.925   |   0.161    | -11.967 |
# | ave_unit_sqft                  |    2.009    |   0.104    |  19.402 |
# | ave_lot_sqft                   |    -0.008   |   0.086    |  -0.091 |
# | ave_income                     |    -1.260   |   0.095    | -13.227 |
# | hhsize                         |    -3.000   |   0.497    |  -6.034 |
# | jobs                           |    0.265    |   0.030    |  8.714  |
# | poor                           |    1.596    |   0.106    |  15.018 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 99
#
# Null Log-liklihood: -3665.715
# Log-liklihood at convergence: -2647.329
# Log-liklihood Ratio: 0.278
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.372    |   0.273    |  1.363  |
# | np.log1p(stories)              |    0.725    |   0.075    |  9.648  |
# | sum_residential_units          |    1.030    |   0.568    |  1.814  |
# | ave_unit_sqft                  |    0.873    |   0.388    |  2.252  |
# | ave_lot_sqft                   |    -1.678   |   0.290    |  -5.790 |
# | ave_income                     |    -1.240   |   0.285    |  -4.348 |
# | hhsize                         |    -1.894   |   1.723    |  -1.099 |
# | jobs                           |    0.939    |   0.083    |  11.270 |
# | poor                           |    -1.471   |   0.387    |  -3.800 |
# +--------------------------------+-------------+------------+---------+
