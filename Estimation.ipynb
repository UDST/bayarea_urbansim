# %%
# %load_ext autoreload
# %autoreload 2
import models
import urbansim.sim.simulation as sim
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sim.run(["build_networks"])
# Out:
# Running model 'build_networks'

# %%
sim.run(["neighborhood_vars"])
# Out:
# Running model 'neighborhood_vars'
# Computing accessibility variables
# Computing sum_residential_units
#     Fields available to accvar = residential_units, _node_id0
#     dataframe = buildings, varname=residential_units
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing sum_nonresidential_units
#     Fields available to accvar = job_spaces, _node_id0
#     dataframe = buildings, varname=job_spaces
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing ave_unit_sqft
#     Fields available to accvar = unit_sqft, general_type, _node_id0
#     Filters = ['general_type == "Residential"']
#     dataframe = buildings, varname=unit_sqft
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Computing ave_lot_sqft
#     Fields available to accvar = unit_lot_size, _node_id0
#     dataframe = buildings, varname=unit_lot_size
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Computing population
#     Fields available to accvar = persons, _node_id0
#     dataframe = households, varname=persons
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing poor
#     Fields available to accvar = persons, income, _node_id0
#     Filters = ['income < 40000']
#     dataframe = households, varname=persons
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing renters
#     Fields available to accvar = tenure, _node_id0
#     Filters = ['tenure == 2']
#     dataframe = households, varname=None
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing sfdu
#     Fields available to accvar = building_type_id, _node_id0
#     Filters = ['building_type_id == 1']
#     dataframe = buildings, varname=None
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing hhsize
#     Fields available to accvar = persons, _node_id0
#     dataframe = households, varname=persons
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Computing jobs
#     Fields available to accvar = _node_id0
#     dataframe = jobs, varname=None
#     radius = 1500, aggregation = AGG_SUM, decay = DECAY_LINEAR
# Computing ave_income
#     Fields available to accvar = income, _node_id0
#     dataframe = households, varname=income
#     radius = 1500, aggregation = AGG_AVE, decay = DECAY_FLAT
# Done

# %% [markdown]
# ## Hedonic Estimation

# %%
sim.run(["rsh_estimate"])
# Out:
# Running model 'rsh_estimate'
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     np.log1p(sale_price_flt)   R-squared:                       0.217
# Model:                                  OLS   Adj. R-squared:                  0.216
# Method:                       Least Squares   F-statistic:                     302.7
# Date:                      Tue, 05 Aug 2014   Prob (F-statistic):               0.00
# Time:                              15:20:41   Log-Likelihood:                -4992.8
# No. Observations:                      8738   AIC:                         1.000e+04
# Df Residuals:                          8729   BIC:                         1.007e+04
# Df Model:                                 8
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        8.6208      0.113     76.353      0.000         8.399     8.842
# I(year_built < 1940)[T.True]     0.0436      0.010      4.357      0.000         0.024     0.063
# I(year_built > 2005)[T.True]     0.0713      0.076      0.932      0.351        -0.079     0.221
# np.log1p(unit_sqft)             -0.4346      0.010    -44.067      0.000        -0.454    -0.415
# np.log1p(unit_lot_size)          0.0634      0.007      8.871      0.000         0.049     0.077
# sum_residential_units            0.0837      0.007     12.529      0.000         0.071     0.097
# ave_unit_sqft                   -0.0016      0.026     -0.060      0.952        -0.053     0.050
# ave_lot_sqft                    -0.2809      0.016    -17.135      0.000        -0.313    -0.249
# ave_income                       0.1621      0.014     11.254      0.000         0.134     0.190
# ==============================================================================
# Omnibus:                      867.822   Durbin-Watson:                   1.324
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2405.219
# Skew:                          -0.551   Prob(JB):                         0.00
# Kurtosis:                       5.322   Cond. No.                         515.
# ==============================================================================

# %%
sim.run(["rrh_estimate"])
# Out:
# Running model 'rrh_estimate'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Tue, 05 Aug 2014   Prob (F-statistic):           1.64e-17
# Time:                        15:20:44   Log-Likelihood:                 95.640
# No. Observations:                 178   AIC:                            -179.3
# Df Residuals:                     172   BIC:                            -160.2
# Df Model:                           5
# =========================================================================================
#                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# Intercept                 2.5404      0.382      6.652      0.000         1.787     3.294
# np.log1p(unit_sqft)      -0.1953      0.030     -6.471      0.000        -0.255    -0.136
# sum_residential_units    -0.0268      0.024     -1.110      0.268        -0.074     0.021
# ave_unit_sqft             0.0006      0.015      0.042      0.967        -0.028     0.030
# ave_lot_sqft             -0.0365      0.027     -1.336      0.183        -0.090     0.017
# jobs                      0.0752      0.015      5.049      0.000         0.046     0.105
# ==============================================================================
# Omnibus:                       11.211   Durbin-Watson:                   1.302
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               27.319
# Skew:                          -0.030   Prob(JB):                     1.17e-06
# Kurtosis:                       4.918   Cond. No.                         662.
# ==============================================================================

# %%
sim.run(["nrh_estimate"])
# Out:
# Running model 'nrh_estimate'
# REGRESSION RESULTS FOR SEGMENT Retail
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.316
# Date:                Tue, 05 Aug 2014   Prob (F-statistic):              0.262
# Time:                        15:20:46   Log-Likelihood:                -73.855
# No. Observations:                 124   AIC:                             159.7
# Df Residuals:                     118   BIC:                             176.6
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.8609      2.476     -0.348      0.729        -5.765     4.043
# I(year_built < 1940)[T.True]    -0.0941      0.105     -0.896      0.372        -0.302     0.114
# I(year_built > 2005)[T.True]    -0.1046      0.246     -0.426      0.671        -0.591     0.382
# np.log1p(stories)               -0.0755      0.110     -0.684      0.495        -0.294     0.143
# ave_income                       0.2976      0.193      1.545      0.125        -0.084     0.679
# jobs                             0.1151      0.046      2.482      0.014         0.023     0.207
# ==============================================================================
# Omnibus:                       15.597   Durbin-Watson:                   2.433
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.800
# Skew:                           0.492   Prob(JB):                     1.24e-07
# Kurtosis:                       5.277   Cond. No.                         910.
# ==============================================================================
# REGRESSION RESULTS FOR SEGMENT Office
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     3.490
# Date:                Tue, 05 Aug 2014   Prob (F-statistic):            0.00426
# Time:                        15:20:47   Log-Likelihood:                -168.79
# No. Observations:                 385   AIC:                             349.6
# Df Residuals:                     379   BIC:                             373.3
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.5244      0.207     17.017      0.000         3.117     3.932
# I(year_built < 1940)[T.True]    -0.0787      0.046     -1.698      0.090        -0.170     0.012
# I(year_built > 2005)[T.True]    -0.0188      0.173     -0.109      0.913        -0.358     0.321
# np.log1p(stories)                0.0493      0.035      1.401      0.162        -0.020     0.118
# ave_income                      -0.0417      0.023     -1.831      0.068        -0.086     0.003
# jobs                             0.0194      0.018      1.079      0.281        -0.016     0.055
# ==============================================================================
# Omnibus:                      106.606   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              544.913
# Skew:                           1.074   Prob(JB):                    4.72e-119
# Kurtosis:                       8.418   Cond. No.                         167.
# ==============================================================================
# REGRESSION RESULTS FOR SEGMENT Industrial
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log1p(rent)   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     931.2
# Date:                Tue, 05 Aug 2014   Prob (F-statistic):           1.19e-66
# Time:                        15:20:47   Log-Likelihood:                -21.284
# No. Observations:                  81   AIC:                             52.57
# Df Residuals:                      76   BIC:                             64.54
# Df Model:                           5
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.5185      0.347      7.266      0.000         1.828     3.209
# I(year_built < 1940)[T.True]     0.0130      0.083      0.157      0.876        -0.152     0.178
# I(year_built > 2005)[T.True]  -1.55e-16   2.69e-16     -0.576      0.566     -6.91e-16  3.81e-16
# np.log1p(stories)                0.0788      0.134      0.588      0.558        -0.188     0.346
# ave_income                      -0.0388      0.039     -0.994      0.323        -0.116     0.039
# jobs                             0.0338      0.035      0.956      0.342        -0.037     0.104
# ==============================================================================
# Omnibus:                        8.537   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               18.123
# Skew:                           0.117   Prob(JB):                     0.000116
# Kurtosis:                       5.305   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is -4.88e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Hedonic Simulation

# %%
sim.run(["rsh_simulate", "rrh_simulate", "nrh_simulate"])
# Out:
# Running model 'rsh_simulate'
# Dropped 3118 rows because they contained nans
# count    138407.000000
# mean        543.457014
# std         171.494622
# min          14.502544
# 25%         461.634613
# 50%         528.977635
# 75%         596.176895
# max       10138.582366
# dtype: float64
# Running model 'rrh_simulate'
# Dropped 2 rows because they contained nans
# count    140780.000000
# mean          3.412905
# std           0.499166
# min           0.630713
# 25%           3.151931
# 50%           3.343975
# 75%           3.580759
# max          15.340111
# dtype: float64
# Running model 'nrh_simulate'
# Dropped 3118 rows because they contained nans
# count    10203.000000
# mean        23.982738
# std          7.233765
# min          0.480017
# 25%         22.415323
# 50%         26.249629
# 75%         28.755369
# max         40.735691
# dtype: float64

# %% [markdown]
# ## LCM Estimation

# %%
sim.run(["hlcmo_estimate"])
# Out:
# Running model 'hlcmo_estimate'
# Dropped 14198 rows because they contained nans
# LCM RESULTS FOR SEGMENT 0
# Null Log-liklihood: -65540.782
# Log-liklihood at convergence: -64525.817
# Log-liklihood Ratio: 0.015
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -1.823   |   0.158    | -11.520 |
# | np.log1p(unit_sqft)               |    -0.887   |   0.065    | -13.701 |
# | sum_residential_units             |    -1.727   |   0.071    | -24.485 |
# | ave_unit_sqft                     |    0.171    |   0.059    |  2.882  |
# | ave_lot_sqft                      |    -0.453   |   0.053    |  -8.633 |
# | ave_income                        |    -1.307   |   0.146    |  -8.967 |
# | hhsize                            |    -3.000   |   0.142    | -21.189 |
# | jobs                              |    0.135    |   0.020    |  6.657  |
# | poor                              |    -0.162   |   0.079    |  -2.059 |
# | population                        |    2.008    |   0.072    |  27.809 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -67870.998
# Log-liklihood at convergence: -67279.702
# Log-liklihood Ratio: 0.009
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -2.272   |   0.154    | -14.792 |
# | np.log1p(unit_sqft)               |    -1.109   |   0.063    | -17.583 |
# | sum_residential_units             |    -1.238   |   0.070    | -17.666 |
# | ave_unit_sqft                     |    0.213    |   0.056    |  3.788  |
# | ave_lot_sqft                      |    -0.674   |   0.052    | -12.957 |
# | ave_income                        |    -0.386   |   0.143    |  -2.695 |
# | hhsize                            |    -2.544   |   0.142    | -17.937 |
# | jobs                              |    0.119    |   0.020    |  5.888  |
# | poor                              |    -0.080   |   0.077    |  -1.030 |
# | population                        |    1.441    |   0.072    |  19.911 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -68013.758
# Log-liklihood at convergence: -67488.611
# Log-liklihood Ratio: 0.008
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -2.800   |   0.154    | -18.169 |
# | np.log1p(unit_sqft)               |    -1.353   |   0.063    | -21.642 |
# | sum_residential_units             |    -1.005   |   0.069    | -14.474 |
# | ave_unit_sqft                     |    0.069    |   0.055    |  1.245  |
# | ave_lot_sqft                      |    -0.763   |   0.053    | -14.494 |
# | ave_income                        |    -0.145   |   0.145    |  -0.999 |
# | hhsize                            |    -2.043   |   0.143    | -14.266 |
# | jobs                              |    0.145    |   0.020    |  7.197  |
# | poor                              |    -0.413   |   0.078    |  -5.296 |
# | population                        |    1.514    |   0.073    |  20.615 |
# +-----------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -68188.755
# Log-liklihood at convergence: -67161.747
# Log-liklihood Ratio: 0.015
#
# +-----------------------------------+-------------+------------+---------+
# | Component                         | Coefficient | Std. Error | T-Score |
# +-----------------------------------+-------------+------------+---------+
# | np.log1p(residential_sales_price) |    -3.000   |   0.147    | -20.475 |
# | np.log1p(unit_sqft)               |    -1.462   |   0.059    | -24.727 |
# | sum_residential_units             |    -1.164   |   0.068    | -16.995 |
# | ave_unit_sqft                     |    0.272    |   0.057    |  4.741  |
# | ave_lot_sqft                      |    -0.888   |   0.052    | -17.165 |
# | ave_income                        |    1.200    |   0.139    |  8.625  |
# | hhsize                            |    -3.000   |   0.145    | -20.756 |
# | jobs                              |    0.221    |   0.020    |  10.895 |
# | poor                              |    -0.208   |   0.077    |  -2.711 |
# | population                        |    1.421    |   0.072    |  19.840 |
# +-----------------------------------+-------------+------------+---------+

# %%
sim.run(["hlcmr_estimate"])
# Out:
# Running model 'hlcmr_estimate'
# Dropped 11825 rows because they contained nans
# LCM RESULTS FOR SEGMENT 0
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -18409.164
# Log-liklihood Ratio: 0.201
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.832    |  -3.604 |
# | np.log1p(unit_sqft)        |    -0.878   |   0.135    |  -6.504 |
# | sum_residential_units      |    -0.320   |   0.132    |  -2.421 |
# | ave_unit_sqft              |    -0.062   |   0.108    |  -0.579 |
# | ave_lot_sqft               |    0.671    |   0.053    |  12.672 |
# | ave_income                 |    -1.054   |   0.137    |  -7.691 |
# | hhsize                     |    -3.000   |   0.282    | -10.622 |
# | jobs                       |    0.311    |   0.062    |  4.992  |
# | poor                       |    0.860    |   0.101    |  8.515  |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20054.547
# Log-liklihood Ratio: 0.129
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.784    |  -3.826 |
# | np.log1p(unit_sqft)        |    -1.050   |   0.129    |  -8.120 |
# | sum_residential_units      |    0.131    |   0.127    |  1.027  |
# | ave_unit_sqft              |    -0.174   |   0.107    |  -1.633 |
# | ave_lot_sqft               |    0.250    |   0.052    |  4.798  |
# | ave_income                 |    -0.895   |   0.133    |  -6.746 |
# | hhsize                     |    -3.000   |   0.269    | -11.151 |
# | jobs                       |    0.179    |   0.059    |  3.027  |
# | poor                       |    0.254    |   0.096    |  2.654  |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -23025.851
# Log-liklihood at convergence: -20732.354
# Log-liklihood Ratio: 0.100
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.735    |  -4.084 |
# | np.log1p(unit_sqft)        |    -1.148   |   0.121    |  -9.480 |
# | sum_residential_units      |    0.457    |   0.123    |  3.711  |
# | ave_unit_sqft              |    -0.529   |   0.105    |  -5.032 |
# | ave_lot_sqft               |    0.135    |   0.050    |  2.664  |
# | ave_income                 |    -0.189   |   0.129    |  -1.472 |
# | hhsize                     |    -3.000   |   0.272    | -11.024 |
# | jobs                       |    0.171    |   0.055    |  3.133  |
# | poor                       |    -0.215   |   0.093    |  -2.319 |
# +----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -23021.246
# Log-liklihood at convergence: -20594.307
# Log-liklihood Ratio: 0.105
#
# +----------------------------+-------------+------------+---------+
# | Component                  | Coefficient | Std. Error | T-Score |
# +----------------------------+-------------+------------+---------+
# | np.log1p(residential_rent) |    -3.000   |   0.706    |  -4.249 |
# | np.log1p(unit_sqft)        |    -1.202   |   0.117    | -10.271 |
# | sum_residential_units      |    0.443    |   0.119    |  3.716  |
# | ave_unit_sqft              |    -0.352   |   0.103    |  -3.426 |
# | ave_lot_sqft               |    0.004    |   0.056    |  0.077  |
# | ave_income                 |    1.102    |   0.130    |  8.502  |
# | hhsize                     |    -3.000   |   0.271    | -11.062 |
# | jobs                       |    0.350    |   0.054    |  6.536  |
# | poor                       |    -0.439   |   0.091    |  -4.820 |
# +----------------------------+-------------+------------+---------+

# %%
sim.run(["elcm_estimate"])
# Out:
# Running model 'elcm_estimate'
# Dropped 142402 rows because they contained nans
# LCM RESULTS FOR SEGMENT 11
# Null Log-liklihood: -2256.533
# Log-liklihood at convergence: -1743.192
# Log-liklihood Ratio: 0.227
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.936    |   0.255    |  3.677  |
# | np.log1p(stories)              |    0.453    |   0.082    |  5.551  |
# | sum_residential_units          |    -1.123   |   0.466    |  -2.410 |
# | ave_unit_sqft                  |    1.500    |   0.260    |  5.776  |
# | ave_lot_sqft                   |    -2.230   |   0.199    | -11.206 |
# | ave_income                     |    -1.169   |   0.256    |  -4.575 |
# | hhsize                         |    -3.000   |   1.268    |  -2.365 |
# | jobs                           |    1.112    |   0.078    |  14.211 |
# | poor                           |    -0.510   |   0.328    |  -1.555 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 21
#
# Null Log-liklihood: -515.779
# Log-liklihood at convergence: -190.762
# Log-liklihood Ratio: 0.630
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.472    |   1.544    |  0.306  |
# | np.log1p(stories)              |    0.364    |   0.219    |  1.661  |
# | sum_residential_units          |    -0.217   |   3.151    |  -0.069 |
# | ave_unit_sqft                  |    -3.000   |   1.832    |  -1.637 |
# | ave_lot_sqft                   |    3.000    |   1.306    |  2.298  |
# | ave_income                     |    3.000    |   1.416    |  2.119  |
# | hhsize                         |    3.000    |   7.242    |  0.414  |
# | jobs                           |    2.513    |   0.566    |  4.442  |
# | poor                           |    -0.446   |   2.245    |  -0.199 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 22
#
# Null Log-liklihood: -22183.105
# Log-liklihood at convergence: -3393.741
# Log-liklihood Ratio: 0.847
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    3.000    |   0.160    |  18.705 |
# | np.log1p(stories)              |    -1.611   |   0.050    | -32.074 |
# | sum_residential_units          |    0.085    |   0.323    |  0.265  |
# | ave_unit_sqft                  |    -2.793   |   0.175    | -15.994 |
# | ave_lot_sqft                   |    3.000    |   0.067    |  44.677 |
# | ave_income                     |    1.655    |   0.177    |  9.339  |
# | hhsize                         |    3.000    |   0.918    |  3.268  |
# | jobs                           |    2.791    |   0.084    |  33.186 |
# | poor                           |    -1.147   |   0.224    |  -5.127 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 23
#
# Null Log-liklihood: -44693.177
# Log-liklihood at convergence: -41041.028
# Log-liklihood Ratio: 0.082
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.551   |   0.035    | -15.660 |
# | np.log1p(stories)              |    0.787    |   0.021    |  37.911 |
# | sum_residential_units          |    -0.818   |   0.063    | -12.956 |
# | ave_unit_sqft                  |    0.293    |   0.047    |  6.219  |
# | ave_lot_sqft                   |    0.738    |   0.032    |  23.079 |
# | ave_income                     |    1.729    |   0.044    |  39.574 |
# | hhsize                         |    1.694    |   0.183    |  9.269  |
# | jobs                           |    0.566    |   0.017    |  33.838 |
# | poor                           |    0.569    |   0.047    |  12.205 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 31
#
# Null Log-liklihood: -29905.975
# Log-liklihood at convergence: -24827.847
# Log-liklihood Ratio: 0.170
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.545    |   0.053    |  10.331 |
# | np.log1p(stories)              |    -0.216   |   0.032    |  -6.765 |
# | sum_residential_units          |    -2.395   |   0.096    | -25.066 |
# | ave_unit_sqft                  |    0.264    |   0.109    |  2.420  |
# | ave_lot_sqft                   |    -1.428   |   0.092    | -15.472 |
# | ave_income                     |    0.387    |   0.052    |  7.474  |
# | hhsize                         |    -3.000   |   0.237    | -12.637 |
# | jobs                           |    1.347    |   0.030    |  44.916 |
# | poor                           |    0.311    |   0.069    |  4.477  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 32
#
# Null Log-liklihood: -18158.186
# Log-liklihood at convergence: -15775.120
# Log-liklihood Ratio: 0.131
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.411   |   0.068    |  -6.050 |
# | np.log1p(stories)              |    0.532    |   0.032    |  16.651 |
# | sum_residential_units          |    -3.000   |   0.102    | -29.376 |
# | ave_unit_sqft                  |    1.829    |   0.098    |  18.689 |
# | ave_lot_sqft                   |    0.163    |   0.075    |  2.158  |
# | ave_income                     |    3.000    |   0.083    |  36.333 |
# | hhsize                         |    0.981    |   0.360    |  2.722  |
# | jobs                           |    1.329    |   0.031    |  43.004 |
# | poor                           |    2.138    |   0.077    |  27.853 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 33
#
# Null Log-liklihood: -19682.497
# Log-liklihood at convergence: -18143.027
# Log-liklihood Ratio: 0.078
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.639   |   0.059    | -10.899 |
# | np.log1p(stories)              |    0.474    |   0.032    |  14.685 |
# | sum_residential_units          |    -1.440   |   0.117    | -12.273 |
# | ave_unit_sqft                  |    0.641    |   0.123    |  5.203  |
# | ave_lot_sqft                   |    -0.008   |   0.099    |  -0.086 |
# | ave_income                     |    1.694    |   0.072    |  23.667 |
# | hhsize                         |    0.471    |   0.315    |  1.498  |
# | jobs                           |    0.916    |   0.032    |  28.544 |
# | poor                           |    0.803    |   0.083    |  9.701  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 42
#
# Null Log-liklihood: -50988.444
# Log-liklihood at convergence: -40575.083
# Log-liklihood Ratio: 0.204
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.009   |   0.036    |  -0.256 |
# | np.log1p(stories)              |    0.859    |   0.016    |  54.666 |
# | sum_residential_units          |    -0.933   |   0.070    | -13.383 |
# | ave_unit_sqft                  |    -0.543   |   0.050    | -10.781 |
# | ave_lot_sqft                   |    0.655    |   0.033    |  19.681 |
# | ave_income                     |    0.564    |   0.046    |  12.255 |
# | hhsize                         |    0.688    |   0.200    |  3.433  |
# | jobs                           |    0.767    |   0.017    |  46.082 |
# | poor                           |    0.115    |   0.049    |  2.358  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 44
#
# Null Log-liklihood: -42551.773
# Log-liklihood at convergence: -38232.685
# Log-liklihood Ratio: 0.102
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.934    |   0.044    |  21.314 |
# | np.log1p(stories)              |    0.689    |   0.021    |  33.298 |
# | sum_residential_units          |    -0.427   |   0.087    |  -4.895 |
# | ave_unit_sqft                  |    0.449    |   0.063    |  7.085  |
# | ave_lot_sqft                   |    -0.015   |   0.044    |  -0.339 |
# | ave_income                     |    0.733    |   0.048    |  15.269 |
# | hhsize                         |    -1.592   |   0.220    |  -7.225 |
# | jobs                           |    0.353    |   0.021    |  17.094 |
# | poor                           |    -0.099   |   0.061    |  -1.610 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 45
#
# Null Log-liklihood: -36302.557
# Log-liklihood at convergence: -33168.776
# Log-liklihood Ratio: 0.086
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.191    |   0.052    |  23.047 |
# | np.log1p(stories)              |    0.422    |   0.022    |  19.177 |
# | sum_residential_units          |    -0.456   |   0.089    |  -5.130 |
# | ave_unit_sqft                  |    0.560    |   0.081    |  6.907  |
# | ave_lot_sqft                   |    0.008    |   0.061    |  0.135  |
# | ave_income                     |    -0.214   |   0.047    |  -4.579 |
# | hhsize                         |    -3.000   |   0.233    | -12.856 |
# | jobs                           |    0.196    |   0.023    |  8.553  |
# | poor                           |    0.194    |   0.060    |  3.228  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 48
#
# Null Log-liklihood: -20502.218
# Log-liklihood at convergence: -15358.353
# Log-liklihood Ratio: 0.251
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.125    |   0.066    |  1.896  |
# | np.log1p(stories)              |    0.418    |   0.026    |  16.113 |
# | sum_residential_units          |    -2.339   |   0.094    | -24.866 |
# | ave_unit_sqft                  |    0.387    |   0.089    |  4.353  |
# | ave_lot_sqft                   |    -0.374   |   0.068    |  -5.467 |
# | ave_income                     |    0.660    |   0.060    |  10.934 |
# | hhsize                         |    -3.000   |   0.236    | -12.694 |
# | jobs                           |    1.012    |   0.021    |  48.405 |
# | poor                           |    0.420    |   0.067    |  6.226  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 49
#
# Null Log-liklihood: -12130.018
# Log-liklihood at convergence: -9306.526
# Log-liklihood Ratio: 0.233
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.358   |   0.110    |  -3.246 |
# | np.log1p(stories)              |    -0.049   |   0.085    |  -0.577 |
# | sum_residential_units          |    -2.959   |   0.118    | -25.145 |
# | ave_unit_sqft                  |    -0.124   |   0.153    |  -0.808 |
# | ave_lot_sqft                   |    0.744    |   0.066    |  11.238 |
# | ave_income                     |    0.068    |   0.144    |  0.469  |
# | hhsize                         |    3.000    |   0.514    |  5.835  |
# | jobs                           |    0.615    |   0.041    |  14.977 |
# | poor                           |    2.073    |   0.064    |  32.172 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 51
#
# Null Log-liklihood: -48082.582
# Log-liklihood at convergence: -35794.456
# Log-liklihood Ratio: 0.256
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.285   |   0.037    |  -7.775 |
# | np.log1p(stories)              |    0.259    |   0.016    |  16.255 |
# | sum_residential_units          |    -0.486   |   0.087    |  -5.594 |
# | ave_unit_sqft                  |    0.584    |   0.076    |  7.667  |
# | ave_lot_sqft                   |    -0.815   |   0.058    | -13.978 |
# | ave_income                     |    -0.220   |   0.047    |  -4.642 |
# | hhsize                         |    -3.000   |   0.259    | -11.579 |
# | jobs                           |    1.189    |   0.019    |  62.758 |
# | poor                           |    -0.710   |   0.062    | -11.471 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 52
#
# Null Log-liklihood: -53931.148
# Log-liklihood at convergence: -25118.226
# Log-liklihood Ratio: 0.534
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.801    |   0.084    |  9.563  |
# | np.log1p(stories)              |    1.035    |   0.016    |  65.913 |
# | sum_residential_units          |    -1.640   |   0.134    | -12.277 |
# | ave_unit_sqft                  |    -1.980   |   0.104    | -19.050 |
# | ave_lot_sqft                   |    0.997    |   0.086    |  11.633 |
# | ave_income                     |    3.000    |   0.070    |  42.730 |
# | hhsize                         |    -3.000   |   0.388    |  -7.723 |
# | jobs                           |    1.431    |   0.031    |  45.914 |
# | poor                           |    0.508    |   0.094    |  5.386  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 53
#
# Null Log-liklihood: -36947.280
# Log-liklihood at convergence: -31637.126
# Log-liklihood Ratio: 0.144
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.331    |   0.054    |  6.090  |
# | np.log1p(stories)              |    0.849    |   0.019    |  43.865 |
# | sum_residential_units          |    0.037    |   0.091    |  0.405  |
# | ave_unit_sqft                  |    -1.220   |   0.055    | -22.152 |
# | ave_lot_sqft                   |    0.122    |   0.035    |  3.447  |
# | ave_income                     |    1.030    |   0.054    |  19.175 |
# | hhsize                         |    -3.000   |   0.270    | -11.123 |
# | jobs                           |    0.324    |   0.018    |  18.148 |
# | poor                           |    -0.418   |   0.067    |  -6.246 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 54
#
# Null Log-liklihood: -55598.220
# Log-liklihood at convergence: -34197.920
# Log-liklihood Ratio: 0.385
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.074    |   0.045    |  1.641  |
# | np.log1p(stories)              |    0.787    |   0.013    |  59.750 |
# | sum_residential_units          |    -0.565   |   0.088    |  -6.447 |
# | ave_unit_sqft                  |    -1.485   |   0.065    | -22.912 |
# | ave_lot_sqft                   |    1.055    |   0.049    |  21.727 |
# | ave_income                     |    1.555    |   0.052    |  30.130 |
# | hhsize                         |    -3.000   |   0.276    | -10.865 |
# | jobs                           |    1.049    |   0.019    |  55.696 |
# | poor                           |    -0.173   |   0.063    |  -2.740 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 55
#
# Null Log-liklihood: -5705.806
# Log-liklihood at convergence: -3304.898
# Log-liklihood Ratio: 0.421
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.686    |   0.189    |  3.630  |
# | np.log1p(stories)              |    0.855    |   0.043    |  19.829 |
# | sum_residential_units          |    -1.653   |   0.379    |  -4.359 |
# | ave_unit_sqft                  |    -1.183   |   0.319    |  -3.713 |
# | ave_lot_sqft                   |    0.173    |   0.256    |  0.673  |
# | ave_income                     |    3.000    |   0.199    |  15.055 |
# | hhsize                         |    -1.744   |   1.059    |  -1.647 |
# | jobs                           |    1.475    |   0.077    |  19.245 |
# | poor                           |    0.594    |   0.272    |  2.184  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 56
#
# Null Log-liklihood: -38651.193
# Log-liklihood at convergence: -32820.029
# Log-liklihood Ratio: 0.151
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.413    |   0.043    |  9.615  |
# | np.log1p(stories)              |    0.651    |   0.017    |  37.251 |
# | sum_residential_units          |    -0.765   |   0.094    |  -8.117 |
# | ave_unit_sqft                  |    -0.660   |   0.070    |  -9.395 |
# | ave_lot_sqft                   |    0.155    |   0.052    |  2.984  |
# | ave_income                     |    0.872    |   0.054    |  16.040 |
# | hhsize                         |    -3.000   |   0.271    | -11.071 |
# | jobs                           |    0.572    |   0.019    |  29.760 |
# | poor                           |    0.021    |   0.068    |  0.307  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 61
#
# Null Log-liklihood: -28602.712
# Log-liklihood at convergence: -26071.887
# Log-liklihood Ratio: 0.088
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.757    |   0.063    |  12.095 |
# | np.log1p(stories)              |    0.920    |   0.025    |  36.807 |
# | sum_residential_units          |    -0.236   |   0.117    |  -2.016 |
# | ave_unit_sqft                  |    0.062    |   0.062    |  0.998  |
# | ave_lot_sqft                   |    -0.294   |   0.026    | -11.249 |
# | ave_income                     |    -0.543   |   0.074    |  -7.340 |
# | hhsize                         |    0.292    |   0.317    |  0.920  |
# | jobs                           |    0.169    |   0.023    |  7.425  |
# | poor                           |    0.165    |   0.087    |  1.904  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 62
#
# Null Log-liklihood: -33871.027
# Log-liklihood at convergence: -31233.357
# Log-liklihood Ratio: 0.078
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    -0.251   |   0.049    |  -5.170 |
# | np.log1p(stories)              |    0.983    |   0.021    |  46.149 |
# | sum_residential_units          |    -0.036   |   0.110    |  -0.330 |
# | ave_unit_sqft                  |    2.506    |   0.072    |  34.728 |
# | ave_lot_sqft                   |    -1.515   |   0.043    | -34.932 |
# | ave_income                     |    0.862    |   0.062    |  13.847 |
# | hhsize                         |    -1.303   |   0.273    |  -4.775 |
# | jobs                           |    0.286    |   0.021    |  13.767 |
# | poor                           |    0.248    |   0.075    |  3.306  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 71
#
# Null Log-liklihood: -33392.089
# Log-liklihood at convergence: -30385.460
# Log-liklihood Ratio: 0.090
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.982    |   0.045    |  21.858 |
# | np.log1p(stories)              |    0.174    |   0.022    |  7.928  |
# | sum_residential_units          |    -0.670   |   0.101    |  -6.634 |
# | ave_unit_sqft                  |    0.390    |   0.094    |  4.143  |
# | ave_lot_sqft                   |    0.131    |   0.072    |  1.831  |
# | ave_income                     |    -0.085   |   0.047    |  -1.804 |
# | hhsize                         |    -3.000   |   0.242    | -12.376 |
# | jobs                           |    0.384    |   0.027    |  14.360 |
# | poor                           |    0.370    |   0.068    |  5.441  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 72
#
# Null Log-liklihood: -40345.896
# Log-liklihood at convergence: -35741.033
# Log-liklihood Ratio: 0.114
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    1.109    |   0.052    |  21.371 |
# | np.log1p(stories)              |    0.325    |   0.020    |  16.048 |
# | sum_residential_units          |    -0.476   |   0.102    |  -4.669 |
# | ave_unit_sqft                  |    -0.203   |   0.078    |  -2.618 |
# | ave_lot_sqft                   |    -0.256   |   0.060    |  -4.292 |
# | ave_income                     |    0.157    |   0.047    |  3.304  |
# | hhsize                         |    -3.000   |   0.233    | -12.856 |
# | jobs                           |    0.477    |   0.021    |  22.285 |
# | poor                           |    0.096    |   0.071    |  1.353  |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 81
#
# Null Log-liklihood: -43095.183
# Log-liklihood at convergence: -39767.050
# Log-liklihood Ratio: 0.077
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.208    |   0.041    |  5.115  |
# | np.log1p(stories)              |    0.585    |   0.019    |  31.213 |
# | sum_residential_units          |    0.002    |   0.082    |  0.022  |
# | ave_unit_sqft                  |    -0.378   |   0.047    |  -7.985 |
# | ave_lot_sqft                   |    0.043    |   0.025    |  1.731  |
# | ave_income                     |    -0.049   |   0.050    |  -0.964 |
# | hhsize                         |    0.150    |   0.228    |  0.656  |
# | jobs                           |    0.421    |   0.016    |  25.700 |
# | poor                           |    -0.178   |   0.060    |  -2.970 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 92
#
# Null Log-liklihood: -40235.372
# Log-liklihood at convergence: -30061.017
# Log-liklihood Ratio: 0.253
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.781    |   0.052    |  14.878 |
# | np.log1p(stories)              |    1.190    |   0.019    |  61.133 |
# | sum_residential_units          |    -1.843   |   0.162    | -11.408 |
# | ave_unit_sqft                  |    1.961    |   0.105    |  18.757 |
# | ave_lot_sqft                   |    0.028    |   0.087    |  0.325  |
# | ave_income                     |    -1.234   |   0.095    | -12.999 |
# | hhsize                         |    -3.000   |   0.496    |  -6.051 |
# | jobs                           |    0.243    |   0.030    |  7.966  |
# | poor                           |    1.565    |   0.107    |  14.653 |
# +--------------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 99
#
# Null Log-liklihood: -3665.715
# Log-liklihood at convergence: -2628.862
# Log-liklihood Ratio: 0.283
#
# +--------------------------------+-------------+------------+---------+
# | Component                      | Coefficient | Std. Error | T-Score |
# +--------------------------------+-------------+------------+---------+
# | np.log1p(non_residential_rent) |    0.399    |   0.273    |  1.464  |
# | np.log1p(stories)              |    0.739    |   0.075    |  9.920  |
# | sum_residential_units          |    1.178    |   0.567    |  2.079  |
# | ave_unit_sqft                  |    0.924    |   0.389    |  2.377  |
# | ave_lot_sqft                   |    -1.766   |   0.291    |  -6.064 |
# | ave_income                     |    -1.340   |   0.284    |  -4.714 |
# | hhsize                         |    -1.502   |   1.717    |  -0.875 |
# | jobs                           |    0.967    |   0.084    |  11.575 |
# | poor                           |    -1.604   |   0.386    |  -4.150 |
# +--------------------------------+-------------+------------+---------+
