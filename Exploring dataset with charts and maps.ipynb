# %%
# try cleaning browser cache if something doesn't work as expected

from IPython import display as d
from bayarea import dataset
import pandas as pd
import vincent
import nvd3
import folium
vincent.core.initialize_notebook()
nvd3.ipynb.initialize_javascript(use_remote=True)
folium.initialize_notebook()
# Out:
# loaded nvd3 IPython extension
# run nvd3.IPython_wrapper.initialize_javascript() to set up the notebook
# help(nvd3.IPython_wrapper.initialize_javascript) for options
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# <link media="all" href="http://nvd3.org/assets/css/nv.d3.css" type="text/css"
#                         rel="stylesheet"/>
# <script src="http://nvd3.org/assets/lib/d3.v3.js"></script>
# <script src="http://nvd3.org/assets/js/nv.d3.js"></script>
# <link rel="stylesheet" href="http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.css" />
# <style>
#     .leaflet-popup-content {
#         color: black !important;
#     }
#
#     .leaflet-control-zoom-in {
#         text-decoration: none !important;
#     }
#
#     .leaflet-control-zoom-out {
#         text-decoration: none !important;
#     }
# </style>
# <script>
#
#   var folium_event = new CustomEvent(
#     "folium_libs_loaded",
#     {bubbles: true, cancelable: true}
#   );
#
#   var load_folium_charts = function(){
#     window.dispatchEvent(folium_event);
#   };
#
#  var load_folium_libs = function(){
#     console.log('Loading all Folium libraries...')
#     $.getScript("http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.js", function(){
#       $.getScript('https://wrobstory.github.io/leaflet-dvf/leaflet-dvf.markers.min.js', function(){
#           if (window['vg'] === undefined){
#             $.getScript("http://wrobstory.github.io/vega/vega.v1.3.3.js", function(){
#               load_folium_charts();
#           });
#         } else {
#           load_folium_charts();
#         }
#       });
#     });
#   };
#
#  if(typeof define === "function" && define.amd){
#       var load_paths = {
#         paths: {
#           topojson:'http://d3js.org/topojson.v1.min',
#           queue: 'http://d3js.org/queue.v1.min',
#           d3: 'http://d3js.org/d3.v3.min'
#         }
#       };
#       var libs = ['d3', 'queue', 'topojson'];
#       for (var i=0; i < libs.length; i++){
#         lib = libs[i]
#         if (window[lib] !== undefined){
#           delete load_paths.paths[lib]
#         };
#       };
#       if (Object.keys(load_paths.paths).length != 0){
#         require.config(load_paths);
#         require(["queue"], function(queue){
#           window.queue = queue;
#         });
#         require(["d3"], function(d3){
#             console.log('Loading from require.js...')
#             window.d3 = d3;
#             require(["topojson"], function(topojson){
#                 window.topojson = topojson;
#                 load_folium_libs();
#             });
#         });
#       } else {
#         load_folium_libs();
#       }
#
#  }else{
#       console.log('Require.js not found!');
#       throw "Require.js not found!"
#  };
#
# </script>

# %%
dset = dataset.BayAreaDataset('data/bayarea.h5')

# %%
homesales = dset.homesales
homesales.head()
# Out:
#                    X          Y                         City  Lot_size  SQft  \
# RecordID
# 378      -122.319420  38.312695                         Napa      1716  6970
# 1222     -121.949692  37.306431                West San Jose      1307   926
# 1263     -121.879135  37.328213  Greater Downtown-metro Area      7332  1100
# 1667     -122.535255  37.943592                    Greenbrae      2600  1381
# 3345     -122.351494  37.927940                     Richmond      5000  1162
#
#           Year_built Sale_price  parcel_id  sales  Sale_price_flt  _node_id0  \
# RecordID
# 378             1974     566500    1612818    NaN          566500      37574
# 1222            1992     399000        NaN    NaN          399000     163651
# 1263            1906     490000        NaN    NaN          490000     169762
# 1667            1975     750000        NaN    NaN          750000     185993
# 3345            1949     380000        NaN    NaN          380000      89760
#
#           _node_id1  _node_id2  _node_id  sale_price_flt  year_built  \
# RecordID
# 378           10500      37236     40761       81.276901        1974
# 1222           4666     161214    176981      430.885529        1992
# 1263           4808     167301    183331      445.454559        1906
# 1667           7659     183318    289143      543.084717        1975
# 3345           1059      88381     97569      327.022369        1949
#
#           unit_lot_size  unit_sqft
# RecordID
# 378                1716       6970
# 1222               1307        926
# 1263               7332       1100
# 1667               2600       1381
# 3345               5000       1162
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Homesales price by decade built

# %%
homesales = homesales[(homesales.Year_built >= 1900) & (homesales.Year_built <= 2010)]
decade_built = homesales.groupby((homesales.Year_built // 10) * 10)
price_decade = decade_built.Sale_price_flt.mean()

# %%
# https://github.com/areski/python-nvd3/issues/50
x = price_decade.index.astype(int)
y = price_decade.values.astype(int)

bar = nvd3.discreteBarChart()
bar.add_serie(x=x, y=y)
bar
# Out:
# <nvd3.discreteBarChart.discreteBarChart instance at 0x46e9878>

# %%
#bar = vincent.Bar(price_decade)
#bar.axis_titles(x='Decade', y="Sale price flt")
#bar.y_axis_properties(title_offset=-35)
#bar.display()

# %%
buildings = dset.buildings
#buildings.groupby('county').size()
# pie chart
# Out:
# WARNING: imputing building square feet where it doesn't exist
# WARNING: imputing lot size where it doesn't exist

# %%
ls_zone = buildings.groupby('zone_id').unit_lot_size.mean()
# should be able to just use the series, opened an issue
ls_zone = ls_zone.to_frame()
ls_zone['zone_id2'] = [int(x) for x in ls_zone.index]
ls_zone.unit_lot_size = ls_zone.unit_lot_size.astype(float)

zones_acres = dset.zones
zones_acres['zone_id2'] = zones_acres.index
zones_acres.acres = zones_acres.acres.astype(float)

# %%
map = folium.Map(location=[37.7792,-122.4391], zoom_start=11)
map.geo_json(geo_path='data/zones.json', data=ls_zone,
             columns=['zone_id2', 'unit_lot_size'], key_on='feature.properties.ZONE_ID',
             fill_color='YlGn')
map.create_map("map.html")
map
# Out:
# <iframe class="folium-iframe" src="files/map.html" style="width: 960px; height: 500px; border: none; margin-left: 75px;" scrolling="no"></iframe>

# %%
homesales.head()
# Out:
#                    X          Y                         City  Lot_size  SQft  \
# RecordID
# 378      -122.319420  38.312695                         Napa      1716  6970
# 1222     -121.949692  37.306431                West San Jose      1307   926
# 1263     -121.879135  37.328213  Greater Downtown-metro Area      7332  1100
# 1667     -122.535255  37.943592                    Greenbrae      2600  1381
# 3345     -122.351494  37.927940                     Richmond      5000  1162
#
#           Year_built Sale_price  parcel_id  sales  Sale_price_flt  _node_id0  \
# RecordID
# 378             1974     566500    1612818    NaN          566500      37574
# 1222            1992     399000        NaN    NaN          399000     163651
# 1263            1906     490000        NaN    NaN          490000     169762
# 1667            1975     750000        NaN    NaN          750000     185993
# 3345            1949     380000        NaN    NaN          380000      89760
#
#           _node_id1  _node_id2  _node_id  sale_price_flt  year_built  \
# RecordID
# 378           10500      37236     40761       81.276901        1974
# 1222           4666     161214    176981      430.885529        1992
# 1263           4808     167301    183331      445.454559        1906
# 1667           7659     183318    289143      543.084717        1975
# 3345           1059      88381     97569      327.022369        1949
#
#           unit_lot_size  unit_sqft
# RecordID
# 378                1716       6970
# 1222               1307        926
# 1263               7332       1100
# 1667               2600       1381
# 3345               5000       1162
#
# [5 rows x 18 columns]

# %%
dset.parcels.head()
# Out:
#            shape_area  tree  county_id  zone_id projects           x  \
# parcel_id
# 1          281.611633     1         38       91      {1}  548474.125
# 2          247.652740     1         38       91      {1}  548618.250
# 3          291.017151     1         38       91      {1}  548722.375
# 4          233.682632     1         38       91      {1}  548675.500
# 5          233.684555     1         38       91      {1}  548670.375
#
#                     y  _node_id0  _node_id1  _node_id2  _node_id
# parcel_id
# 1          4179481.50     119221      11569     117106    128904
# 2          4179506.25     115538      11569     113423    125155
# 3          4179475.75     116905       6976     234072    126552
# 4          4179456.75     115539       6976     113424    125156
# 5          4179487.00     115538       6976     113423    125155
#
# [5 rows x 11 columns]

# %%
merged = pd.merge(dset.homesales, dset.parcels, left_on='parcel_id', right_index=True)

# %%
sales_zone = merged.groupby('zone_id').size()
sales_zone = sales_zone.to_frame()
sales_zone['zone_id2'] = [int(x) for x in sales_zone.index]
sales_zone['sales_count'] = sales_zone[0]

# %%
map = folium.Map(location=[37.7792,-122.4391], zoom_start=11)
map.geo_json(geo_path='data/zones.json', data=sales_zone,
             columns=['zone_id2', 'sales_count'], key_on='feature.properties.ZONE_ID',
             fill_color='OrRd')
map.create_map("map2.html")
map
# Out:
# <iframe class="folium-iframe" src="files/map2.html" style="width: 960px; height: 500px; border: none; margin-left: 75px;" scrolling="no"></iframe>

# %%
dset.nodes.head()
# Out:
# WARNING: fetching precomputed nodes off of disk
#          _graph_id  _node_id  sum_residential_units  sum_nonresidential_units  \
# node_id
# 8                0         0                  2.556                     6.005
# 9                0         1                  2.718                     6.626
# 10               0         2                  2.460                     7.223
# 11               0         3                  2.575                     6.905
# 12               0         4                  2.562                     6.863
#
#          ave_unit_sqft  ave_lot_sqft  ave_income  population   poor  hhsize  \
# node_id
# 8                7.834         13.04      11.150       3.750  1.862   3.684
# 9                7.768          0.00      11.012       3.462  2.368   3.650
# 10               7.787          0.00      10.944       2.577  2.474   2.667
# 11               7.770          0.00      10.899       2.032  1.892   2.750
# 12               7.770          0.00      10.899       1.983  1.840   2.750
#
#            jobs  sfdu  renters
# node_id
# 8        10.189     0        0
# 9        11.575     0        0
# 10       11.557     0        0
# 11       11.110     0        0
# 12       11.077     0        0
#
# [5 rows x 13 columns]

# %%
dset.households.head()
# Out:
#               building_id  building_type_id  income  persons  tenure  \
# household_id
# 1                  136325                 1   27310        1       2
# 4                  133982                 2   25000        1       2
# 5                   25633                 1    3100        1       1
# 6                  132596                 2    7200        1       1
# 7                   57108                 1   27310        1       2
#
#               income_quartile  HHINCOME
# household_id
# 1                           0     2.731
# 4                           0     2.500
# 5                           0     0.310
# 6                           0     0.720
# 7                           0     2.731
#
# [5 rows x 7 columns]

# %%
dset.buildings.keys()
# Out:
# Index([u'parcel_id', u'building_type', u'residential_units', u'building_sqft', u'stories', u'building_type_id', u'year_built', u'tenure', u'id', u'building', u'scenario', u'county', u'lot_size', u'rent', u'rental', u'general_type', u'unit_sqft', u'unit_lot_size', u'x', u'y', u'_node_id0', u'_node_id1', u'_node_id2', u'_node_id', u'sqft_per_job', u'non_residential_units', u'zone_id'], dtype='object')
