# %%
# %load_ext autoreload
# %autoreload 2
from urbansim.sim import simulation as sim
import models
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sim.run(["travel_model_output"])
# Out:
# Running model 'travel_model_output'
# Time to execute model 'travel_model_output': 2.12s
# Total time to execute: 2.12s

# %%
sim.get_table("travel_model_output").to_frame().describe()
# Out:
#                gid          tract          area         acres        tothh  \
# count  1454.000000    1375.000000  1.454000e+03   1454.000000   189.000000
# mean    727.500000  363333.978182  1.254134e+07    287.909582  1828.507937
# std     419.877958  181354.334928  6.745452e+07   1548.542656  1159.263250
# min       1.000000   10100.000000  5.525473e+04      1.268000     4.000000
# 25%     364.250000  250850.000000  9.383170e+05     21.540750  1012.000000
# 50%     727.500000  420600.000000  1.609932e+06     36.959000  1746.000000
# 75%    1090.750000  504650.500000  3.612029e+06     82.921001  2534.000000
# max    1454.000000  613800.000000  1.516080e+09  34804.417969  6951.000000
#
#               hhpop         sfdu         mfdu      hhincq1     hhincq2  \
# count    189.000000   188.000000   189.000000   189.000000  188.000000
# mean    4128.793651   573.595745  1257.947090   398.089947  315.468085
# std     2730.493421   692.512689   930.841782   364.021141  201.738418
# ...

# %%
print sim.get_table("travel_model_output").to_frame()
# Out:
#           gid   tract          area         acres  tothh  hhpop  sfdu  mfdu  \
# zone_id
# 1442      525  126100  5.272042e+06    121.028999    NaN    NaN   NaN   NaN
# 1434      508  114100  7.820342e+06    179.529999    NaN    NaN   NaN   NaN
# 246       784  605000  4.247868e+06     97.517998    NaN    NaN   NaN   NaN
# 1312      560  201800  7.597325e+08  17441.058594    NaN    NaN   NaN   NaN
# 705      1205  512507  2.783539e+07    639.013000    NaN    NaN   NaN   NaN
# 1291      552  201002  7.535315e+07   1729.869995    NaN    NaN   NaN   NaN
# 875      1448     NaN  6.510720e+06    149.466003    NaN    NaN   NaN   NaN
# 1087      435  356002  1.121201e+08   2573.924072    NaN    NaN   NaN   NaN
# 1316      561  201900  1.817411e+08   4172.201172    NaN    NaN   NaN   NaN
# 26        577   11800  5.525473e+04      1.268000    578   1117    19   559
# 1416      534  132200  3.011291e+08   6912.972168    NaN    NaN   NaN   NaN
# ...

# %%
print sim.get_table("travel_model_output").to_frame().to_csv('toTM.csv')
# Out:
# None
