# %%
if 'sim' not in globals():
    import os; os.chdir('..')
from urbansim.sim import simulation as sim
import models

# %%
sim.run(["travel_model_output"])
# Out:
# Running model 'travel_model_output'

# %%
sim.get_table("travel_model_output").to_frame().describe()
# Out:
#                gid          tract          area         acres       HHINC1  \
# count  1454.000000    1375.000000  1.454000e+03   1454.000000   189.000000
# mean    727.500000  363334.074182  1.254134e+07    287.909796   398.089947
# std     419.877958  181354.334928  6.745452e+07   1548.542656   364.021141
# min       1.000000   10100.000000  5.525473e+04      1.268000     1.000000
# 25%     364.250000  250850.000000  9.383170e+05     21.540750   182.000000
# 50%     727.500000  420600.000000  1.609932e+06     36.959000   323.000000
# 75%    1090.750000  504650.500000  3.612029e+06     82.921001   496.000000
# max    1454.000000  613800.000000  1.516080e+09  34804.417969  2765.000000
#
#            HHINC2       HHINC3       HHINC4
# count  188.000000   189.000000   189.000000
# mean   315.468085   394.142857   722.476190
# std    201.738418   263.085771   588.422355
# min      1.000000     1.000000     1.000000
# 25%    163.500000   207.000000   279.000000
# ...
